# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/piloto/blob/main/analyse30repo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf repositorio*

# %%
import pandas as pd
import os
import requests

# %%
# Dada uma URL, checa se e valida
# retorna True se for valida
def check_url(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            return True
        else:
            return False
    except requests.exceptions.RequestException:
        return False

# Ler arquivo .csv e carrega em um DataFrame
URL = 'https://raw.githubusercontent.com/armandossrecife/teste/main/listaderepositorios.csv'
df_repositorios = pd.read_csv(filepath_or_buffer=URL, sep=';')

print(f'Colunas do dataframe: {df_repositorios.columns}')

# Ler as url do dataframe e carrega em uma lista
lista_url_repositorios = df_repositorios['Git Repository'].tolist()
lista_urls_validas = []
lista_urls_invalidas = []

# Verifica se a URL e valida
for each in lista_url_repositorios:
    url_valida = check_url(each)
    print(f'Checa se a URL {each} é valida: {url_valida}')
    if url_valida:
        lista_urls_validas.append(each)
    else:
        lista_urls_invalidas.append(each)

if len(lista_urls_invalidas) > 0:
    print('Lista de URL inválidas: ')
    for each in lista_urls_invalidas:
        print(each)
else:
    print('Não há URL inválidas. ')
# Out:
# Colunas do dataframe: Index(['Category', 'Project', 'Git Repository', 'Description'], dtype='object')
# Checa se a URL https://github.com/apache/accumulo.git é valida: True
# Checa se a URL https://github.com/apache/calcite.git é valida: True
# Checa se a URL https://github.com/apache/cassandra.git é valida: True
# Checa se a URL https://github.com/apache/chukwa.git é valida: True
# Checa se a URL https://github.com/apache/jackrabbit.git é valida: True
# Checa se a URL https://github.com/FasterXML/jackson.git é valida: True
# Checa se a URL https://github.com/apache/jspwiki.git é valida: True
# Checa se a URL https://github.com/square/retrofit.git é valida: True
# Checa se a URL https://github.com/spring-projects/spring-boot.git é valida: True
# Checa se a URL https://github.com/apache/struts.git é valida: True
# Checa se a URL https://github.com/elastic/elasticsearch.git é valida: True
# Checa se a URL https://github.com/apache/jena.git é valida: True
# Checa se a URL https://github.com/apache/lucene-solr.git é valida: True
# Checa se a URL https://github.com/apache/tika.git é valida: True
# Checa se a URL https://github.com/apache/ant-ivy.git é valida: True
# Checa se a URL https://github.com/jenkinsci/jenkins.git é valida: True
# Checa se a URL https://github.com/spearce/jgit.git é valida: True
# Checa se a URL https://github.com/SeleniumHQ/selenium.git é valida: True
# Checa se a URL https://github.com/cbeust/testng.git é valida: True
# Checa se a URL https://github.com/apache/pdfbox.git é valida: True
# Checa se a URL https://github.com/apache/poi.git é valida: True
# Checa se a URL https://github.com/apache/xerces2-j.git é valida: True
# Checa se a URL https://github.com/apache/druid.git é valida: True
# Checa se a URL https://github.com/pgjdbc/pgjdbc.git é valida: True
# Checa se a URL https://github.com/apache/activemq.git é valida: True
# Checa se a URL https://github.com/apache/mina.git é valida: True
# Checa se a URL https://github.com/libgdx/libgdx.git é valida: True
# Checa se a URL https://github.com/alibaba/fastjson.git é valida: True
# Checa se a URL https://github.com/google/gson.git é valida: True
# Checa se a URL https://github.com/google/guava.git é valida: True
# Não há URL inválidas.

# %%
# !pip3 install gitpython
# Out:
# Requirement already satisfied: gitpython in /usr/local/lib/python3.10/dist-packages (3.1.31)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython) (5.0.0)

# %%
# Clona varios repositorios simultaneamente usando threads
import os
import threading
import datetime
import pandas as pd
from git import Repo

# Dado um comando de so, faz a execucao via python
def executa_comando_so(comando):
  try:
    os.system(comando)
    print(f'Comando: {comando} executado com sucesso!')
  except:
    print(f'Erro ao executar o comando {comando}')

# Dada uma url do git, salva no diretorio. Tambem adiciona o tempo de clonagem em uma lista de informacoes
def my_clone(git_url, repo_dir, lista):
  try:
    Repo.clone_from(git_url, repo_dir)
    tempo = datetime.datetime.now()
    print(f'Clonagem do repo {git_url} concluída com sucesso! -> instante: {tempo}')
    elemento = (repo_dir, tempo)
    lista.append(elemento)
  except Exception as ex:
    print(f"Erro ao clonar o repo: {git_url} - {str(ex)}")


def clona_repositorios(qtd_repositorios, lista_urls, lista_threads, lista_tempo_inicio, lista_tempo_conclusao):
  for i in range(qtd_repositorios):
    nome = 'repositorio'+str(i+1)
    tdi = threading.Thread(target=my_clone, args=(lista_urls[i], nome, lista_tempo_conclusao)) # Thread que inicia cada clonagem
    tdi.name = 'Thread-'+str(i+1) # nome do objeto thread recem criado
    inicio_thread = datetime.datetime.now() # instante que o clone inicia
    print(f"Thread {i+1} iniciada em {inicio_thread} - clonando {nome}:{lista_urls[i]}...")
    lista_threads.append(tdi) # insere a thread recem criada na lista de threads
    elemento = (nome, inicio_thread)
    lista_tempo_inicio.append(elemento)
    tdi.start() # inicia a thread
  for each in lista_threads:
    each.join()

def mostra_tempo_clonagens(lista_tempo_inicio, lista_tempo_conclusao):
  for t1 in lista_tempo_inicio:
    for t2 in lista_tempo_conclusao:
      if (t1[0]==t2[0]):
        print(f"Tempo de download do {t1[0]} é: {t2[1]-t1[1]} s")

# Ler arquivo .csv e carrega em um DataFrame
URL = 'https://raw.githubusercontent.com/armandossrecife/teste/main/listaderepositorios.csv'
df_repositorios = pd.read_csv(filepath_or_buffer=URL, sep=';')

# Ler as url do dataframe e carrega em uma lista
lista_url_repositorios = df_repositorios['Git Repository'].tolist()

lista_urls = lista_url_repositorios
lista_tempo_conclusao = []
lista_threads = [] # lista que armazena dos threads que vao fazer os clones
lista_tempo_inicio = [] # lista que vai guardar o instante de inicio de cada thread de clonagem

print("bloco de clonagem...")
tempo1 = datetime.datetime.now()
clona_repositorios(len(lista_urls), lista_urls, lista_threads, lista_tempo_inicio, lista_tempo_conclusao)
tempo2 = datetime.datetime.now()

print("")
print(f"Tempo total de {len(lista_urls)} clonagens: {tempo2-tempo1}s")
print("")
print(f'Lista de tempos de inicio: {lista_tempo_inicio}')
print(f'Lista de tempos de conclusao: {lista_tempo_conclusao}')
print("")
mostra_tempo_clonagens(lista_tempo_inicio, lista_tempo_conclusao)
# Out:
# bloco de clonagem...
# Thread 1 iniciada em 2023-07-09 13:54:17.954621 - clonando repositorio1:https://github.com/apache/accumulo.git...
# Thread 2 iniciada em 2023-07-09 13:54:17.955126 - clonando repositorio2:https://github.com/apache/calcite.git...
# Thread 3 iniciada em 2023-07-09 13:54:17.957505 - clonando repositorio3:https://github.com/apache/cassandra.git...
# Thread 4 iniciada em 2023-07-09 13:54:17.961251 - clonando repositorio4:https://github.com/apache/chukwa.git...
# Clonagem do repo https://github.com/FasterXML/jackson.git concluída com sucesso! -> instante: 2023-07-09 13:54:51.773605
# Clonagem do repo https://github.com/apache/mina.git concluída com sucesso! -> instante: 2023-07-09 13:54:54.556074
# Clonagem do repo https://github.com/alibaba/fastjson.git concluída com sucesso! -> instante: 2023-07-09 13:55:05.165636
# Clonagem do repo https://github.com/apache/chukwa.git concluída com sucesso! -> instante: 2023-07-09 13:55:06.073252
# Clonagem do repo https://github.com/apache/ant-ivy.git concluída com sucesso! -> instante: 2023-07-09 13:55:08.271870
# Clonagem do repo https://github.com/cbeust/testng.git concluída com sucesso! -> instante: 2023-07-09 13:55:11.262242
# Clonagem do repo https://github.com/spearce/jgit.git concluída com sucesso! -> instante: 2023-07-09 13:55:12.170213
# Clonagem do repo https://github.com/pgjdbc/pgjdbc.git concluída com sucesso! -> instante: 2023-07-09 13:55:19.284948
# Clonagem do repo https://github.com/apache/xerces2-j.git concluída com sucesso! -> instante: 2023-07-09 13:55:42.867364
# Clonagem do repo https://github.com/apache/struts.git concluída com sucesso! -> instante: 2023-07-09 13:56:00.027942
# Clonagem do repo https://github.com/apache/jspwiki.git concluída com sucesso! -> instante: 2023-07-09 13:56:05.219573
# Clonagem do repo https://github.com/apache/jackrabbit.git concluída com sucesso! -> instante: 2023-07-09 13:56:16.571153
# Clonagem do repo https://github.com/apache/pdfbox.git concluída com sucesso! -> instante: 2023-07-09 13:56:19.077457
# Clonagem do repo https://github.com/apache/activemq.git concluída com sucesso! -> instante: 2023-07-09 13:56:30.824103
# Clonagem do repo https://github.com/apache/calcite.git concluída com sucesso! -> instante: 2023-07-09 13:57:22.388787
# Clonagem do repo https://github.com/apache/accumulo.git concluída com sucesso! -> instante: 2023-07-09 13:57:24.501018
# Clonagem do repo https://github.com/apache/tika.git concluída com sucesso! -> instante: 2023-07-09 13:57:39.123389
# Clonagem do repo https://github.com/apache/poi.git concluída com sucesso! -> instante: 2023-07-09 13:58:02.080726
# Clonagem do repo https://github.com/jenkinsci/jenkins.git concluída com sucesso! -> instante: 2023-07-09 13:58:19.751740
# Clonagem do repo https://github.com/apache/druid.git concluída com sucesso! -> instante: 2023-07-09 13:59:05.364986
# Clonagem do repo https://github.com/spring-projects/spring-boot.git concluída com sucesso! -> instante: 2023-07-09 13:59:09.702725
# Clonagem do repo https://github.com/apache/jena.git concluída com sucesso! -> instante: 2023-07-09 13:59:42.775036
# Clonagem do repo https://github.com/apache/cassandra.git concluída com sucesso! -> instante: 2023-07-09 14:00:25.086686
# Clonagem do repo https://github.com/libgdx/libgdx.git concluída com sucesso! -> instante: 2023-07-09 14:00:44.804045
# Clonagem do repo https://github.com/google/guava.git concluída com sucesso! -> instante: 2023-07-09 14:01:41.867510
# Clonagem do repo https://github.com/apache/lucene-solr.git concluída com sucesso! -> instante: 2023-07-09 14:02:50.140173
# Clonagem do repo https://github.com/SeleniumHQ/selenium.git concluída com sucesso! -> instante: 2023-07-09 14:02:54.047154
# Clonagem do repo https://github.com/elastic/elasticsearch.git concluída com sucesso! -> instante: 2023-07-09 14:03:13.270279
#
', datetime.datetime(2023, 7, 9, 13, 55, 19, 284948)), ('repositorio22', datetime.datetime(2023, 7, 9, 13, 55, 42, 867364)), ('repositorio10', datetime.datetime(2023, 7, 9, 13, 56, 0, 27942)), ('repositorio7', datetime.datetime(2023, 7, 9, 13, 56, 5, 219573)), ('repositorio5', datetime.datetime(2023, 7, 9, 13, 56, 16, 571153)), ('repositorio20', datetime.datetime(2023, 7, 9, 13, 56, 19, 77457)), ('repositorio25', datetime.datetime(2023, 7, 9, 13, 56, 30, 824103)), ('repositorio2', datetime.datetime(2023, 7, 9, 13, 57, 22, 388787)), ('repositorio1', datetime.datetime(2023, 7, 9, 13, 57, 24, 501018)), ('repositorio14', datetime.datetime(2023, 7, 9, 13, 57, 39, 123389)), ('repositorio21', datetime.datetime(2023, 7, 9, 13, 58, 2, 80726)), ('repositorio16', datetime.datetime(2023, 7, 9, 13, 58, 19, 751740)), ('repositorio23', datetime.datetime(2023, 7, 9, 13, 59, 5, 364986)), ('repositorio9', datetime.datetime(2023, 7, 9, 13, 59, 9, 702725)), ('repositorio12', datetime.datetime(2023, 7, 9, 13, 59, 42, 775036)), ('repositorio3', datetime.datetime(2023, 7, 9, 14, 0, 25, 86686)), ('repositorio27', datetime.datetime(2023, 7, 9, 14, 0, 44, 804045)), ('repositorio30', datetime.datetime(2023, 7, 9, 14, 1, 41, 867510)), ('repositorio13', datetime.datetime(2023, 7, 9, 14, 2, 50, 140173)), ('repositorio18', datetime.datetime(2023, 7, 9, 14, 2, 54, 47154)), ('repositorio11', datetime.datetime(2023, 7, 9, 14, 3, 13, 270279))]
#
# Tempo de download do repositorio1 é: 0:03:06.546397 s
# Tempo de download do repositorio2 é: 0:03:04.433661 s
# Tempo de download do repositorio3 é: 0:06:07.129181 s
# Tempo de download do repositorio4 é: 0:00:48.112001 s
# Tempo de download do repositorio5 é: 0:01:58.606959 s
# Tempo de download do repositorio6 é: 0:00:33.805338 s
# Tempo de download do repositorio7 é: 0:01:47.247650 s
# Tempo de download do repositorio8 é: 0:00:14.259126 s
# Tempo de download do repositorio9 é: 0:04:51.726757 s
# Tempo de download do repositorio10 é: 0:01:42.040555 s
# Tempo de download do repositorio11 é: 0:08:55.279386 s
# Tempo de download do repositorio12 é: 0:05:24.773556 s
# Tempo de download do repositorio13 é: 0:08:32.132607 s
# Tempo de download do repositorio14 é: 0:03:21.114173 s
# Tempo de download do repositorio15 é: 0:00:50.260019 s
# Tempo de download do repositorio16 é: 0:04:01.733325 s
# Tempo de download do repositorio17 é: 0:00:54.146606 s
# Tempo de download do repositorio18 é: 0:08:36.015953 s
# Tempo de download do repositorio19 é: 0:00:53.222597 s
# Tempo de download do repositorio20 é: 0:02:01.030378 s
# Tempo de download do repositorio21 é: 0:03:44.024723 s
# Tempo de download do repositorio22 é: 0:01:24.799511 s
# Tempo de download do repositorio23 é: 0:04:47.284276 s
# Tempo de download do repositorio24 é: 0:01:01.177750 s
# Tempo de download do repositorio25 é: 0:02:12.703588 s
# Tempo de download do repositorio26 é: 0:00:36.420216 s
# Tempo de download do repositorio27 é: 0:06:26.638634 s
# Tempo de download do repositorio28 é: 0:00:46.945650 s
# Tempo de download do repositorio29 é: 0:00:18.756598 s
# Tempo de download do repositorio30 é: 0:07:23.588619 s

# %%
URL = 'https://raw.githubusercontent.com/armandossrecife/teste/main/l31repositorios.csv'
URL2 = 'https://raw.githubusercontent.com/armandossrecife/teste/main/l31repositoriosurl.csv'

df_repositorios_src = pd.read_csv(URL)
df_complemento = pd.read_csv(URL2)
df_complemento['nome'] = df_repositorios_src['projeto']
df_complemento['source_java'] = df_repositorios_src['source']

df_repositorios = df_complemento.copy()
df_repositorios = df_repositorios[['repositorio', 'url', 'nome', 'source_java']]
df_repositorios['source_java'] = df_repositorios['source_java'].str.replace('.','/')

df_repositorios.to_csv('l31repositoriossrc.csv', index=False)

lista_src = df_repositorios_src['source'].tolist()
#for i, each in enumerate(lista_src):
#    print(f'{i}, {each}')
# Out:
# <ipython-input-15-eeea6bacbc5a>:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_repositorios['source_java'] = df_repositorios['source_java'].str.replace('.','/')

# %%
df_repositorios
# Out:
#       repositorio                                                url  \
# 0    repositorio1             https://github.com/apache/accumulo.git
# 1    repositorio2              https://github.com/apache/calcite.git
# 2    repositorio3            https://github.com/apache/cassandra.git
# 3    repositorio4               https://github.com/apache/chukwa.git
# 4    repositorio5           https://github.com/apache/jackrabbit.git
# 5    repositorio6           https://github.com/FasterXML/jackson.git
# 6    repositorio7              https://github.com/apache/jspwiki.git
# 7    repositorio8             https://github.com/square/retrofit.git
# 8    repositorio9  https://github.com/spring-projects/spring-boot...
# 9   repositorio10               https://github.com/apache/struts.git
# 10  repositorio11       https://github.com/elastic/elasticsearch.git
# 11  repositorio12                 https://github.com/apache/jena.git
# 12  repositorio13          https://github.com/apache/lucene-solr.git
# 13  repositorio14                 https://github.com/apache/tika.git
# 14  repositorio15              https://github.com/apache/ant-ivy.git
# 15  repositorio16           https://github.com/jenkinsci/jenkins.git
# 16  repositorio17                https://github.com/spearce/jgit.git
# 17  repositorio18         https://github.com/SeleniumHQ/selenium.git
# 18  repositorio19               https://github.com/cbeust/testng.git
# 19  repositorio20               https://github.com/apache/pdfbox.git
# 20  repositorio21                  https://github.com/apache/poi.git
# 21  repositorio22            https://github.com/apache/xerces2-j.git
# 22  repositorio23                https://github.com/apache/druid.git
# 23  repositorio24               https://github.com/pgjdbc/pgjdbc.git
# 24  repositorio25             https://github.com/apache/activemq.git
# 25  repositorio26                 https://github.com/apache/mina.git
# 26  repositorio27               https://github.com/libgdx/libgdx.git
# 27  repositorio28            https://github.com/alibaba/fastjson.git
# 28  repositorio29                 https://github.com/google/gson.git
# 29  repositorio30                https://github.com/google/guava.git
#
#              nome                                    source_java
# 0        accumulo                             core/src/main/java
# 1         calcite                             core/src/main/java
# 2       cassandra                                       src/java
# 3          chukwa                             core/src/main/java
# 4      jackrabbit                  jackrabbit-core/src/main/java
# 5         jackson            nao tem o src the Java JSON library
# 6         jspwiki                      jspwiki-api/src/main/java
# 7        retrofit                         retrofit/src/main/java
# 8     spring-boot  spring-boot-project/spring-boot/src/main/java
# 9          struts                             core/src/main/java
# 10  elasticsearch                           server/src/main/java
# 11           jena                        jena-core/src/main/java
# 12    lucene-solr                      nao tem o src lucene-solr
# 13           tika                        tika-core/src/main/java
# 14        ant-ivy                                       src/java
# 15        jenkins                             core/src/main/java
# 16           jgit          org/eclipse/jgit/src/org/eclipse/jgit
# 17       selenium                                       java/src
# 18         testng                      testng-core/src/main/java
# 19         pdfbox                           pdfbox/src/main/java
# 20            poi                              poi/src/main/java
# 21      xerces2-j                          src/org/apache/xerces
# 22          druid                           server/src/main/java
# 23         pgjdbc                           pgjdbc/src/main/java
# 24       activemq                    activemq-http/src/main/java
# 25           mina                             core/src/main/java
# 26         libgdx                                        gdx/src
# 27       fastjson                                  src/main/java
# 28           gson                             gson/src/main/java
# 29          guava                                      guava/src

# %%
def checa_sub_pasta(subdir, directory):
    if subdir in os.listdir(directory):
        print(f"{subdir} exists in {directory}")
    else:
        print(f"{subdir} doesn't exist in {directory}")

def is_path_in_dir(directory_path, file_path):
    rel_path = os.path.relpath(file_path, directory_path)
    return not rel_path.startswith('..')

def checa_file_path(directory_path, file_path):
    if is_path_in_dir(directory_path, file_path):
        print('File path is in directory')
    else:
        print('File path is not in directory')

def checa_sub_path(i, sub_path, repositorio):
    current_path = os.getcwd()
    abs_sub_path = current_path + '/' + repositorio + '/'+ sub_path
    print(f"Analisa {lista_src[i]} em {repositorio} - {os.path.exists(abs_sub_path)}")
    return os.path.exists(abs_sub_path)

# %%
# URL da lista de 31 repositorios do Darius Sas
URL = 'https://raw.githubusercontent.com/armandossrecife/teste/main/l31repositoriossrc.csv'

# Carrega os dados dos repositorios em um DataFrame
df_repositorios = pd.read_csv(URL)

lista_repositorios = df_repositorios['repositorio'].tolist()
lista_src = df_repositorios['source_java'].tolist()

lista_checa = []

lista_urls = df_repositorios['url'].to_list()

# Checa se os subdiretorios source existem nos repositorios
for i, repositorio in enumerate(lista_repositorios):
    resultado = checa_sub_path(i, sub_path=lista_src[i], repositorio=repositorio)
    lista_checa.append(resultado)

dict_temp = {
    'repositorio':lista_repositorios,
    'url':lista_urls,
    'src':lista_src,
    'checa':lista_checa
}

df_checa_repositorios = pd.DataFrame(dict_temp)
# Out:
# Analisa core/src/main/java em repositorio1 - True
# Analisa core/src/main/java em repositorio2 - True
# Analisa src/java em repositorio3 - True
# Analisa core/src/main/java em repositorio4 - True
# Analisa jackrabbit-core/src/main/java em repositorio5 - True
# Analisa nao tem o src the Java JSON library em repositorio6 - False
# Analisa jspwiki-api/src/main/java em repositorio7 - True
# Analisa retrofit/src/main/java em repositorio8 - True
# Analisa spring-boot-project/spring-boot/src/main/java em repositorio9 - True
# Analisa core/src/main/java em repositorio10 - True
# Analisa server/src/main/java em repositorio11 - True
# Analisa jena-core/src/main/java em repositorio12 - True
# Analisa nao tem o src lucene-solr em repositorio13 - False
# Analisa tika-core/src/main/java em repositorio14 - True
# Analisa src/java em repositorio15 - True
# Analisa core/src/main/java em repositorio16 - True
# Analisa org.eclipse.jgit/src em repositorio17 - True
# Analisa java/src em repositorio18 - True
# Analisa testng-core/src/main/java em repositorio19 - True
# Analisa pdfbox/src/main/java em repositorio20 - True
# Analisa poi/src/main/java em repositorio21 - True
# Analisa src/org/apache/xerces em repositorio22 - True
# Analisa server/src/main/java em repositorio23 - True
# Analisa pgjdbc/src/main/java em repositorio24 - True
# Analisa activemq-http/src/main/java em repositorio25 - True
# Analisa core/src/main/java em repositorio26 - True
# Analisa gdx/src em repositorio27 - True
# Analisa src/main/java em repositorio28 - True
# Analisa gson/src/main/java em repositorio29 - True
# Analisa guava/src em repositorio30 - True

# %%
df_checa_repositorios
# Out:
#       repositorio                                                url  \
# 0    repositorio1             https://github.com/apache/accumulo.git
# 1    repositorio2              https://github.com/apache/calcite.git
# 2    repositorio3            https://github.com/apache/cassandra.git
# 3    repositorio4               https://github.com/apache/chukwa.git
# 4    repositorio5           https://github.com/apache/jackrabbit.git
# 5    repositorio6           https://github.com/FasterXML/jackson.git
# 6    repositorio7              https://github.com/apache/jspwiki.git
# 7    repositorio8             https://github.com/square/retrofit.git
# 8    repositorio9  https://github.com/spring-projects/spring-boot...
# 9   repositorio10               https://github.com/apache/struts.git
# 10  repositorio11       https://github.com/elastic/elasticsearch.git
# 11  repositorio12                 https://github.com/apache/jena.git
# 12  repositorio13          https://github.com/apache/lucene-solr.git
# 13  repositorio14                 https://github.com/apache/tika.git
# 14  repositorio15              https://github.com/apache/ant-ivy.git
# 15  repositorio16           https://github.com/jenkinsci/jenkins.git
# 16  repositorio17                https://github.com/spearce/jgit.git
# 17  repositorio18         https://github.com/SeleniumHQ/selenium.git
# 18  repositorio19               https://github.com/cbeust/testng.git
# 19  repositorio20               https://github.com/apache/pdfbox.git
# 20  repositorio21                  https://github.com/apache/poi.git
# 21  repositorio22            https://github.com/apache/xerces2-j.git
# 22  repositorio23                https://github.com/apache/druid.git
# 23  repositorio24               https://github.com/pgjdbc/pgjdbc.git
# 24  repositorio25             https://github.com/apache/activemq.git
# 25  repositorio26                 https://github.com/apache/mina.git
# 26  repositorio27               https://github.com/libgdx/libgdx.git
# 27  repositorio28            https://github.com/alibaba/fastjson.git
# 28  repositorio29                 https://github.com/google/gson.git
# 29  repositorio30                https://github.com/google/guava.git
#
#                                               src  checa
# 0                              core/src/main/java   True
# 1                              core/src/main/java   True
# 2                                        src/java   True
# 3                              core/src/main/java   True
# 4                   jackrabbit-core/src/main/java   True
# 5             nao tem o src the Java JSON library  False
# 6                       jspwiki-api/src/main/java   True
# 7                          retrofit/src/main/java   True
# 8   spring-boot-project/spring-boot/src/main/java   True
# 9                              core/src/main/java   True
# 10                           server/src/main/java   True
# 11                        jena-core/src/main/java   True
# 12                      nao tem o src lucene-solr  False
# 13                        tika-core/src/main/java   True
# 14                                       src/java   True
# 15                             core/src/main/java   True
# 16                           org.eclipse.jgit/src   True
# 17                                       java/src   True
# 18                      testng-core/src/main/java   True
# 19                           pdfbox/src/main/java   True
# 20                              poi/src/main/java   True
# 21                          src/org/apache/xerces   True
# 22                           server/src/main/java   True
# 23                           pgjdbc/src/main/java   True
# 24                    activemq-http/src/main/java   True
# 25                             core/src/main/java   True
# 26                                        gdx/src   True
# 27                                  src/main/java   True
# 28                             gson/src/main/java   True
# 29                                      guava/src   True
