# %% [markdown]
# <a href="https://colab.research.google.com/github/armandossrecife/piloto/blob/main/teste_correlacao_issue_tracker_by_bug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dependencies

# %%
print('Install dependencies...')
print('Update apt. ')
# !sudo apt update > apt_update.log
print('Install software-properties-common.')
# !sudo apt install software-properties-common > spc.log
print('Add ppa-git-core repository.')
# !sudo add-apt-repository -y ppa:git-core/ppa > ppa_git_core.log
print('Install the latest version of git.')
# !sudo apt install -y git > install_git.log
# !git --version > git_version.log
print('Install pydriller')
# !pip3 install pydriller > install_pydriller.log
# !pip3 list | grep PyDriller > versao_pydriller.log
print('Install gitpython.')
# !pip3 install gitpython > install_gitpython.log
print('Install Jira Python lib.')
# !pip install jira > install_jira_python.log
print('All depenpencies installed!')
# !cat *.log > install.log
print('Details in install.log')
# Out:
# Install dependencies...
# Update apt.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Install software-properties-common.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Add ppa-git-core repository.
# Install the latest version of git.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 2.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Install pydriller
# Install gitpython.
# Install Jira Python lib.
# All depenpencies installed!
# Details in install.log

# %% [markdown]
# # Apoio

# %%
# 1. import libraries and modules
import pandas as pd
import pydriller
from jira import JIRA
import os
import subprocess
import requests
import threading
import datetime
import configparser # para manipular arquivos .conf
import tqdm
from datetime import datetime, timedelta
import re
import tqdm

# 2. Define variables
github_repo_url = 'https://github.com/apache/cassandra.git'
SERVIDOR_JIRA = 'https://issues.apache.org/jira'

def create_file_credentials():
  file_name = 'credentials.conf'
  try:
    with open(file_name, mode='w') as f_credentials:
      f_credentials.write('[credentials]')
      f_credentials.write('\n')
      f_credentials.write('username = ?')
      f_credentials.write('\n')
      f_credentials.write('password = ?')
      print(f'The file {file_name}. You have to update username/password')
  except Exception as ex:
    print(f'Erro during creation of {file_name}: {str(ex)} ')

def connect_to_jira_server(url_server):
  file_name = 'credentials.conf'
  try:
    config = configparser.ConfigParser()
    config.read(file_name)
    username = config['credentials']['username']
    password = config['credentials']['password']

    # Create a JIRA client instance
    jira = JIRA(
        server=url_server,  # Replace with the Cassandra JIRA server URL
        basic_auth=(username, password),  # Replace with your JIRA credentials
    )
    print(f'Servidor {url_server} acessado com sucesso!')
  except Exception as ex:
    print(f'Erro ao acessar o Jira: {str(ex)}')
  return jira

#!cd cassandra && git rev-list --count HEAD
def get_total_commit_count(repository_path):
    command = ["git", "rev-list", "--count", "HEAD"]
    result = subprocess.run(command, cwd=repository_path, stdout=subprocess.PIPE, text=True)
    total_commit_count = int(result.stdout.strip())
    return total_commit_count

def generate_intervals_between_dates(date1, date2, distance=120):
  start_date = datetime(date1[0], date1[1], date1[2])
  end_date = datetime(date2[0], date2[1], date2[2])
  interval_days = distance
  # Initialize a list to store the intervals
  intervals = []
  # Initialize the current date as the start date
  current_date = start_date
  # Loop to generate intervals until the current date is less than or equal to the end date
  while current_date < end_date:
      interval = (current_date, current_date + timedelta(days=interval_days - 1))
      intervals.append(interval)
      current_date += timedelta(days=interval_days)
  return intervals

def convert_interval_dates(dates):
  list_interval_dates = []
  for each in dates:
    date1 = each[0]
    # Convert the date to a string in the format "YYYY/MM/DD".
    str_date1 = date1.strftime("%Y/%m/%d")
    date2 = each[1]
    str_date2 = date2.strftime("%Y/%m/%d")
    elemento = str_date1, str_date2
    list_interval_dates.append(elemento)
  return list_interval_dates

def gera_lista_sentencas(project_name, dates):
  lista_sentencas = []
  for each in dates:
    str_date1 = each[0].strftime("%Y/%m/%d")
    str_date2 = each[1].strftime("%Y/%m/%d")
    sentenca = f'project={project_name} and created>="{str_date1}" and created<="{str_date2}"'
    lista_sentencas.append(sentenca)
  return lista_sentencas

def lista_acesso_jira(lista_sentencas):
  print('Aguarde...')
  t1 = datetime.now()
  lista_issues_by_date = []
  for each in lista_sentencas:
    issues_by_date_temp = jira.search_issues(each,maxResults=1000)
    print(each, len(issues_by_date_temp))
    lista_issues_by_date.append(issues_by_date_temp)
  t2 = datetime.now()
  print(t2)
  print(f'Tempo da consulta: {t2-t1}')
  return lista_issues_by_date

def find_cassandra_pattern(input_string):
    # Define the pattern using regular expression
    pattern = r'(CASSANDRA-\d+)'

    # Use re.search() to find the pattern in the input_string
    match = re.search(pattern, input_string)

    # If a match is found, return the matched pattern; otherwise, return None
    if match:
        return match.group(1)
    else:
        return None

# extrai o issue tracker salvo na mensagem de cada commit
def extract_cassandra_issue(text_content, project_id='CASSANDRA-'):
  """
  Extract the CASSANDRA-XYZ issue from the text.

  Args:
    text: The text to extract the issue from.

  Returns:
    The issue number, or None if the issue cannot be found.
  """

  issues_number = []

  lines = text_content.split('\n')
  for line in lines:
    issue_number = find_cassandra_pattern(line)
    if issue_number:
      issues_number.append(issue_number)
  return issues_number

def get_modified_files_from_commit(key):
  list_files = []
  MESSAGE = 0
  MODIFIED_FILES = 1
  QTD_MODIFIED_FILES = 2
  for each in key:
    if each in dict_commit_modified_files.keys():
      if dict_commit_modified_files[each] is not None:
        list_files.append(dict_commit_modified_files[each][MODIFIED_FILES])
  return list_files

### Analisa os issues que foram salvos em commits ###

def get_list_issues_number(commits_file_path='/content/cassandra/all_commits_msg.txt'):
  print('Gera a lista de issue number que aparece nas mensagens dos commits.')
  with open(commits_file_path, mode='r') as f_commits_msg:
    conteudo = f_commits_msg.read()

  list_issue_number = extract_cassandra_issue(text_content=conteudo, project_id='CASSANDRA-')

  clean_list_issue_number = []
  for each in list_issue_number:
    item = each.split()[0]
    item = item.replace(")", "")
    if item != 'CASSANDRA-' and item != 'CASSANDRA-CASSANDRA':
      clean_list_issue_number.append(item)

  return clean_list_issue_number


def get_list_cassandra_issues_analyzed(clean_list_issue_number):
  print('Gera a lista de issues analisados que aparecem nas mensagens dos commits')
  total_items = len(clean_list_issue_number)
  i = 0
  iterable_list_issue_number = tqdm.tqdm(clean_list_issue_number, total=total_items)
  # Faz a limpeza para garantir o id do Issue tracker
  list_cassandra_issues_analyzed = []
  for each in iterable_list_issue_number:
    #issue = each.split()
    #if len(issue) == 1:
    #  elemento = issue[0].replace('"', '')
    #  elemento = elemento.replace(")", "")
    #  elemento = elemento.replace(".", "")
    list_cassandra_issues_analyzed.append(each)
    percentage = (i + 1) / total_items * 100
    iterable_list_issue_number.set_description(f"Progress Message Analysis")
    i += 1

  return list_cassandra_issues_analyzed

### Cria um Dataframe referente aos issues coletados ###

def generate_dict_all_issues(concatenated_list):
  dict_all_issues = {}

  list_key, list_summary, list_status, list_description, list_priority, list_timeestimate, list_timespent, list_issuetype = list(), list(), list(), list(), list(), list(), list(), list()

  i = 1
  for issue in concatenated_list:
      list_key.append(issue.key)
      list_summary.append(issue.fields.summary)
      list_status.append(issue.fields.status)
      list_description.append(issue.fields.description)
      list_priority.append(issue.fields.priority)
      list_timespent.append(issue.fields.timespent)
      list_timeestimate.append(issue.fields.timeestimate)
      list_issuetype.append(issue.fields.issuetype)
      i += 1

  dict_all_issues['key'] = list_key
  dict_all_issues['issue_type'] = list_issuetype
  dict_all_issues['summary'] = list_summary
  dict_all_issues['status'] = list_status
  dict_all_issues['description'] = list_description
  dict_all_issues['priority'] = list_priority
  dict_all_issues['timespent'] = list_timespent
  dict_all_issues['timeestimate'] = list_timeestimate

  return dict_all_issues

### Gera os dicionários com commits e arquivos modificados ###
def extract_commits_info(total_commit_count):
  print('Extrai informações dos commits.')
  # 4. Extract Commit
  total_commits = total_commit_count
  dict_commit_modified_files = {}
  i = 0

  iterable_commits = tqdm.tqdm(pydriller.Repository("cassandra").traverse_commits(), total=total_commits)

  for commit in iterable_commits:
    list_modified_files = []
    for m in commit.modified_files:
      list_modified_files.append(m.filename)
    qtd_modified_files = len(list_modified_files)
    commit_message = commit.msg
    elemento = (commit_message, list_modified_files, qtd_modified_files)
    dict_commit_modified_files[commit.hash] = elemento
    percentage = (i + 1) / total_commits * 100
    iterable_commits.set_description(f"Progress Commit Analysis")
    i += 1

  return dict_commit_modified_files

def generate_dict_message_commits_valido(dict_commit_modified_files, list_cassandra_issues_analyzed):
  print('Gera o dicionário com issues em mensagens validas dos commits')
  dict_message_commits_valido = {}

  i = 0
  total_commits = len(dict_commit_modified_files)
  iterable_dict_commit_modified_files = tqdm.tqdm(dict_commit_modified_files.items(), total=total_commits)

  for k,v in iterable_dict_commit_modified_files:
    if v[0] is not None:
      for cassandra_issue in list_cassandra_issues_analyzed:
        if cassandra_issue != 'CASSANDRA-' and cassandra_issue in str(v[0]):
          dict_message_commits_valido[k] = cassandra_issue
          break
    percentage = (i + 1) / total_commits * 100
    iterable_dict_commit_modified_files.set_description(f"Progress Dict Message Commit Analysis")
    i += 1

  return dict_message_commits_valido

def generate_dict_key_commit_valido(lista_key_cassandra_all_issues, dict_message_commits_valido):
  print('Gera o dicionario de key commit valido')
  dict_key_commit_valido = {}
  list_commits_by_key = []

  i = 0
  j = 0
  total_issues = len(lista_key_cassandra_all_issues)
  iterable_lista_key_cassandra_all_issues = tqdm.tqdm(lista_key_cassandra_all_issues, total=total_issues)

  for each_issue in iterable_lista_key_cassandra_all_issues:
    list_commits_by_key = []
    for k,v in dict_message_commits_valido.items():
      if each_issue == v:
        i +=1
        list_commits_by_key.append(k)
    dict_key_commit_valido[each_issue] = list_commits_by_key
    percentage = (j + 1) / total_issues * 100
    iterable_lista_key_cassandra_all_issues.set_description(f"Progress Dict Key Commit Analysis")
    j += 1

  return dict_key_commit_valido

# %% [markdown]
# # Acessa o Servidor do Jira e cria uma instância de conexão

# %%
create_file_credentials()
# Out:
# The file credentials.conf. You have to update username/password

# %%
jira = connect_to_jira_server(url_server=SERVIDOR_JIRA)
# Out:
# Servidor https://issues.apache.org/jira acessado com sucesso!

# %% [markdown]
# # Extrai Commits do repositório

# %%
# !git clone https://github.com/apache/cassandra.git
# Out:
# Cloning into 'cassandra'...
# remote: Enumerating objects: 399017, done.
# remote: Counting objects: 100% (2086/2086), done.
# remote: Compressing objects: 100% (941/941), done.
# remote: Total 399017 (delta 962), reused 1758 (delta 821), pack-reused 396931
# Receiving objects: 100% (399017/399017), 394.70 MiB | 26.24 MiB/s, done.
# Resolving deltas: 100% (232929/232929), done.

# %%
# Mostra todos os commits
# !cd cassandra && git log --pretty="%H;%ai;%s" > all_commits_full.txt
# !cd cassandra && git log --pretty="%H %s" > all_commits_msg.txt
# !echo "10 primeiros commits all_commits_msg.txt"
# !cd cassandra && head all_commits_msg.txt
# !echo "..."

# Total de commits registrados entre as versões cassandra-3.0.0...cassandra-3.11.11
# !echo "Total de commits registrados "
# !cd cassandra && cat all_commits_msg.txt | wc -l
# Out:
# 10 primeiros commits all_commits_msg.txt
# 188df44c8cce77aebb05f2daa7a54001c98f50b9 Merge branch 'cassandra-5.0' into trunk
# 15f355a0062148e1ca511e8fc515e0cba380790d Remove wrong assertion in SSTableLoader
# 89065ffa2189861c0437fd1f1a5748df006e8907 Merge branch 'cassandra-5.0' into trunk
# 2b23fc58aa86a1cd0c98f97ddcf43305869d041e Fix accessing java.nio.Bits.TOTAL_CAPACITY in Java17
# 830f88d4ab2aaa1f7b88b90747a808d0a4e2a708 Merge branch 'cassandra-5.0' into trunk
# 6708499e4c930f7733894e6076b925fb151d9251 Remove metrics-reporter-config dependency
# 1959502d8b16212479eecb076c89945c3f0f180c Merge branch 'cassandra-5.0' into trunk
# 00c0cbb958db570e759e685da85dc840de7dd739 Merge branch 'cassandra-4.1' into cassandra-5.0
# 3d220b5a6e2528b7b9f89074fe48dc6556977dc1 Merge branch 'cassandra-4.0' into cassandra-4.1
# b2093ef3216bb38aa56fd7d9902412a6f49232bc Select automatic native port when starting the server in CQLTester
# ...
# Total de commits registrados
# 29156

# %%
# Dados do 1o commit e do ultimo commit
# !head /content/cassandra/all_commits_full.txt -n 1
# !tail /content/cassandra/all_commits_full.txt -n 1
# Out:
# 188df44c8cce77aebb05f2daa7a54001c98f50b9;2023-09-15 09:07:45 +0200;Merge branch 'cassandra-5.0' into trunk
# 1f91e99223b0d1b7ed8390400d4a06ac08e4aa85;2009-03-02 07:57:22 +0000;git-svn-id: https://svn.apache.org/repos/asf/incubator/cassandra/trunk@749218 13f79535-47bb-0310-9956-ffa450edef68

# %% [markdown]
# # Analisa os issues que foram salvos em commits

# %%
clean_list_issue_number = get_list_issues_number()
# Out:
# Gera a lista de issue number que aparece nas mensagens dos commits.

# %%
list_cassandra_issues_analyzed = get_list_cassandra_issues_analyzed(clean_list_issue_number)
# Out:
# Gera a lista de issues analisados que aparecem nas mensagens dos commits
# Progress Message Analysis:  90%|████████▉ | 4260/4734 [00:10<00:01, 385.88it/s]

# %%
print(f'{len(list_cassandra_issues_analyzed)} commits com Id de issue: {list_cassandra_issues_analyzed}')

# %% [markdown]
# # Gera intervalo de datas entre o 1o e o último commit

# %%
dates = generate_intervals_between_dates(date1=(2009,3,2), date2=(2023,9,12), distance=120)
print(convert_interval_dates(dates))

# %%
gera_lista_sentencas(project_name='CASSANDRA', dates=dates)

# %% [markdown]
# # Coleta os issues do Servidor do Jira

# %%
issues_by_date_2009_2023 = lista_acesso_jira(lista_sentencas=gera_lista_sentencas(project_name='CASSANDRA', dates=dates))

# %%
# Use a list comprehension to concatenate the sublists
concatenated_list = [item for sublist in issues_by_date_2009_2023 for item in sublist]
len(concatenated_list)

# %% [markdown]
# # Cria um Dataframe referente aos issues coletados

# %%
dict_all_issues = generate_dict_all_issues(concatenated_list)
df_cassandra_all_issues = pd.DataFrame(dict_all_issues)
df_cassandra_all_issues
# Out:
#                    key   issue_type  \
# 0        CASSANDRA-263          Bug
# 1        CASSANDRA-262          Bug
# 2        CASSANDRA-261          Bug
# 3        CASSANDRA-260          Bug
# 4        CASSANDRA-259  New Feature
# ...                ...          ...
# 18570  CASSANDRA-18769          Bug
# 18571  CASSANDRA-18768  New Feature
# 18572  CASSANDRA-18767          Bug
# 18573  CASSANDRA-18766          Bug
# 18574  CASSANDRA-18765          Bug
#
#                                                  summary         status  \
# 0       get_slice needs to support desc from last column       Resolved
# 1         get_slice needs to allow returning all columns       Resolved
# 2                         get_slice needs offset + limit       Resolved
# 3      Unable to read all columns in a column family ...       Resolved
# 4                            LRU cache for key positions       Resolved
# ...                                                  ...            ...
# 18570  Fix flaky test: org.apache.cassandra.cql3.Memt...       Resolved
# 18571  Harry changes required for CEP-21 testing (NTS...  Triage Needed
# 18572         tablestats should show speculative retries       Resolved
# 18573                 high speculative retries on v4.1.3           Open
# 18574       Add CASSANDRA-14227 to 5.0 new features page       Resolved
#
#                                              description priority  timespent  \
# 0      At the moment there's no way to ask for a slic...   Normal        NaN
# 1      Right now get_slice requires you to enter a 'l...   Normal        NaN
# 2      Right now get_slice does not allow you to prov...   Normal        NaN
# 3      Since r788516 the typical 'get all columns for...   Normal        NaN
# 4      add cache like the old touch cache, but workin...   Normal        NaN
# ...                                                  ...      ...        ...
# 18570  {noformat}\r\njava.lang.reflect.InaccessibleOb...   Normal        NaN
# 18571                                               None   Normal        NaN
# 18572  NodeProbe makes [provisions|https://github.com...   Normal        NaN
# 18573  There are up to 10+ times higher speculative r...   Normal        NaN
# 18574  The [page|https://cassandra.apache.org/doc/tru...   Normal        NaN
#
#        timeestimate
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 18570           NaN
# 18571           NaN
# 18572           NaN
# 18573           NaN
# 18574           NaN
#
# [18575 rows x 8 columns]

# %%
lista_key_cassandra_all_issues = df_cassandra_all_issues.key.unique().tolist()
len(lista_key_cassandra_all_issues)
# Out:
# 18575

# %% [markdown]
# ## Cria um Dataframe contendo apenas os issues do tipo Bug

# %%
df_cassandra_all_issues['issue_type'] = df_cassandra_all_issues['issue_type'].astype(str)

# %%
df_cassandra_all_issues.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18575 entries, 0 to 18574
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           18575 non-null  object
#  1   issue_type    18575 non-null  object
#  2   summary       18575 non-null  object
#  3   status        18575 non-null  object
#  4   description   18072 non-null  object
#  5   priority      18575 non-null  object
#  6   timespent     1147 non-null   float64
#  7   timeestimate  1540 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 1.1+ MB

# %%
df_cassandra_bug_issues = df_cassandra_all_issues.query("issue_type=='Bug'")
df_cassandra_bug_issues
# Out:
#                    key issue_type  \
# 0        CASSANDRA-263        Bug
# 1        CASSANDRA-262        Bug
# 2        CASSANDRA-261        Bug
# 3        CASSANDRA-260        Bug
# 8        CASSANDRA-255        Bug
# ...                ...        ...
# 18569  CASSANDRA-18770        Bug
# 18570  CASSANDRA-18769        Bug
# 18572  CASSANDRA-18767        Bug
# 18573  CASSANDRA-18766        Bug
# 18574  CASSANDRA-18765        Bug
#
#                                                  summary         status  \
# 0       get_slice needs to support desc from last column       Resolved
# 1         get_slice needs to allow returning all columns       Resolved
# 2                         get_slice needs offset + limit       Resolved
# 3      Unable to read all columns in a column family ...       Resolved
# 8                        Supercolumn deserialization bug       Resolved
# ...                                                  ...            ...
# 18569  Open File Descriptors not cleared post upgrade...  Triage Needed
# 18570  Fix flaky test: org.apache.cassandra.cql3.Memt...       Resolved
# 18572         tablestats should show speculative retries       Resolved
# 18573                 high speculative retries on v4.1.3           Open
# 18574       Add CASSANDRA-14227 to 5.0 new features page       Resolved
#
#                                              description priority  timespent  \
# 0      At the moment there's no way to ask for a slic...   Normal        NaN
# 1      Right now get_slice requires you to enter a 'l...   Normal        NaN
# 2      Right now get_slice does not allow you to prov...   Normal        NaN
# 3      Since r788516 the typical 'get all columns for...   Normal        NaN
# 8                                                   None   Normal        NaN
# ...                                                  ...      ...        ...
# 18569  \r\n\r\nWe recently upgraded our fleet of ~250...   Normal        NaN
# 18570  {noformat}\r\njava.lang.reflect.InaccessibleOb...   Normal        NaN
# 18572  NodeProbe makes [provisions|https://github.com...   Normal        NaN
# 18573  There are up to 10+ times higher speculative r...   Normal        NaN
# 18574  The [page|https://cassandra.apache.org/doc/tru...   Normal        NaN
#
#        timeestimate
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 8               NaN
# ...             ...
# 18569           NaN
# 18570           NaN
# 18572           NaN
# 18573           NaN
# 18574           NaN
#
# [10118 rows x 8 columns]

# %%
lista_key_cassandra_bug_issues = df_cassandra_bug_issues.key.unique().tolist()
len(lista_key_cassandra_bug_issues)
# Out:
# 10118

# %% [markdown]
# # Gera os dicionários com commits e arquivos modificados

# %%
repository_path = "cassandra"
total_commit_count = get_total_commit_count(repository_path)
print("Total number of commits:", total_commit_count)
# Out:
# Total number of commits: 29156

# %%
dict_commit_modified_files = extract_commits_info(total_commit_count)
# Out:
# Extrai informações dos commits.
# Progress Commit Analysis: 100%|██████████| 29156/29156 [06:49<00:00, 71.17it/s]

# %%
dict_message_commits_valido = generate_dict_message_commits_valido(dict_commit_modified_files, list_cassandra_issues_analyzed)
# Out:
# Gera o dicionário com issues em mensagens validas dos commits
# Progress Dict Message Commit Analysis: 100%|██████████| 29156/29156 [02:06<00:00, 229.77it/s]

# %%
# cria um dicionario contendo os keys e commits dos issues do tipo Bug
dict_key_commit_valido_only_bugs = generate_dict_key_commit_valido(lista_key_cassandra_bug_issues, dict_message_commits_valido)
len(dict_key_commit_valido_only_bugs)
# Out:
# Gera o dicionario de key commit valido
# Progress Dict Key Commit Analysis: 100%|██████████| 10118/10118 [00:52<00:00, 194.43it/s]
# 10118

# %%
key_commits_by_key_only_bugs = list(dict_key_commit_valido_only_bugs.keys() )
commits_commits_by_key_only_bugs = list(dict_key_commit_valido_only_bugs.values() )

dict_key_commit_valido_temp_only_bugs = {
    'key': key_commits_by_key_only_bugs,
    'commits': commits_commits_by_key_only_bugs
}

df_key_commit_valido_only_bugs = pd.DataFrame(data=dict_key_commit_valido_temp_only_bugs)
df_key_commit_valido_only_bugs
# Out:
#                    key                                            commits
# 0        CASSANDRA-263         [9164940f41972e3611d1ad38a903ca39562e6feb]
# 1        CASSANDRA-262         [ef203cf00070fd719f87db9dd2384b8bc116ebd6]
# 2        CASSANDRA-261         [cdd8b170628176924c21db1cb6dcbecf4c7f2148]
# 3        CASSANDRA-260                                                 []
# 4        CASSANDRA-255  [27d66d8269d5f52dd29b98cac0b41574291f16ad, 963...
# ...                ...                                                ...
# 10113  CASSANDRA-18770                                                 []
# 10114  CASSANDRA-18769                                                 []
# 10115  CASSANDRA-18767                                                 []
# 10116  CASSANDRA-18766                                                 []
# 10117  CASSANDRA-18765                                                 []
#
# [10118 rows x 2 columns]

# %%
df_key_commit_valido_only_bugs['modified_files'] = df_key_commit_valido_only_bugs['commits'].apply(get_modified_files_from_commit)

# %%
df_key_commit_valido_only_bugs
# Out:
#                    key                                            commits  \
# 0        CASSANDRA-263         [9164940f41972e3611d1ad38a903ca39562e6feb]
# 1        CASSANDRA-262         [ef203cf00070fd719f87db9dd2384b8bc116ebd6]
# 2        CASSANDRA-261         [cdd8b170628176924c21db1cb6dcbecf4c7f2148]
# 3        CASSANDRA-260                                                 []
# 4        CASSANDRA-255  [27d66d8269d5f52dd29b98cac0b41574291f16ad, 963...
# ...                ...                                                ...
# 10113  CASSANDRA-18770                                                 []
# 10114  CASSANDRA-18769                                                 []
# 10115  CASSANDRA-18767                                                 []
# 10116  CASSANDRA-18766                                                 []
# 10117  CASSANDRA-18765                                                 []
#
#                                           modified_files
# 0      [[Memtable.java, SSTableSliceIterator.java, Sl...
# 1                   [[cassandra.thrift, Cassandra.java]]
# 2      [[cassandra.thrift, Cassandra.java, CliClient....
# 3                                                     []
# 4      [[Column.java, ColumnFamily.java, SuperColumn....
# ...                                                  ...
# 10113                                                 []
# 10114                                                 []
# 10115                                                 []
# 10116                                                 []
# 10117                                                 []
#
# [10118 rows x 3 columns]

# %%
df_cassandra_bug_issues
# Out:
#                    key issue_type  \
# 0        CASSANDRA-263        Bug
# 1        CASSANDRA-262        Bug
# 2        CASSANDRA-261        Bug
# 3        CASSANDRA-260        Bug
# 8        CASSANDRA-255        Bug
# ...                ...        ...
# 18569  CASSANDRA-18770        Bug
# 18570  CASSANDRA-18769        Bug
# 18572  CASSANDRA-18767        Bug
# 18573  CASSANDRA-18766        Bug
# 18574  CASSANDRA-18765        Bug
#
#                                                  summary         status  \
# 0       get_slice needs to support desc from last column       Resolved
# 1         get_slice needs to allow returning all columns       Resolved
# 2                         get_slice needs offset + limit       Resolved
# 3      Unable to read all columns in a column family ...       Resolved
# 8                        Supercolumn deserialization bug       Resolved
# ...                                                  ...            ...
# 18569  Open File Descriptors not cleared post upgrade...  Triage Needed
# 18570  Fix flaky test: org.apache.cassandra.cql3.Memt...       Resolved
# 18572         tablestats should show speculative retries       Resolved
# 18573                 high speculative retries on v4.1.3           Open
# 18574       Add CASSANDRA-14227 to 5.0 new features page       Resolved
#
#                                              description priority  timespent  \
# 0      At the moment there's no way to ask for a slic...   Normal        NaN
# 1      Right now get_slice requires you to enter a 'l...   Normal        NaN
# 2      Right now get_slice does not allow you to prov...   Normal        NaN
# 3      Since r788516 the typical 'get all columns for...   Normal        NaN
# 8                                                   None   Normal        NaN
# ...                                                  ...      ...        ...
# 18569  \r\n\r\nWe recently upgraded our fleet of ~250...   Normal        NaN
# 18570  {noformat}\r\njava.lang.reflect.InaccessibleOb...   Normal        NaN
# 18572  NodeProbe makes [provisions|https://github.com...   Normal        NaN
# 18573  There are up to 10+ times higher speculative r...   Normal        NaN
# 18574  The [page|https://cassandra.apache.org/doc/tru...   Normal        NaN
#
#        timeestimate
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 8               NaN
# ...             ...
# 18569           NaN
# 18570           NaN
# 18572           NaN
# 18573           NaN
# 18574           NaN
#
# [10118 rows x 8 columns]

# %%
df_cassandra_bug_issues['commits'] = df_key_commit_valido_only_bugs['commits']
# Out:
# <ipython-input-119-ede3a8575f5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cassandra_bug_issues['commits'] = df_key_commit_valido_only_bugs['commits']

# %%
colunas_validas = ['key', 'issue_type', 'summary', 'status', 'commits']
df_cassandra_bug_issues = df_cassandra_bug_issues[colunas_validas]

# %%
df_cassandra_bug_issues.dropna(inplace=True)
# Out:
# <ipython-input-128-91518e4680ed>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cassandra_bug_issues.dropna(inplace=True)

# %%
df_cassandra_bug_issues['modified_files'] = df_key_commit_valido_only_bugs['modified_files']
# Out:
# <ipython-input-131-85c9150d9dea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cassandra_bug_issues['modified_files'] = df_key_commit_valido_only_bugs['modified_files']

# %%
df_cassandra_bug_issues[['key', 'issue_type', 'commits', 'modified_files']]
# Out:
#                   key issue_type                                     commits  \
# 0       CASSANDRA-263        Bug  [9164940f41972e3611d1ad38a903ca39562e6feb]
# 1       CASSANDRA-262        Bug  [ef203cf00070fd719f87db9dd2384b8bc116ebd6]
# 2       CASSANDRA-261        Bug  [cdd8b170628176924c21db1cb6dcbecf4c7f2148]
# 3       CASSANDRA-260        Bug                                          []
# 8       CASSANDRA-255        Bug                                          []
# ...               ...        ...                                         ...
# 10110  CASSANDRA-9681        Bug                                          []
# 10111  CASSANDRA-9680        Bug  [9be8369ae65be8eb4848eb9ef58e2909a8d89016]
# 10112  CASSANDRA-9679        Bug                                          []
# 10115  CASSANDRA-9676        Bug                                          []
# 10116  CASSANDRA-9675        Bug                                          []
#
#                                           modified_files
# 0      [[Memtable.java, SSTableSliceIterator.java, Sl...
# 1                   [[cassandra.thrift, Cassandra.java]]
# 2      [[cassandra.thrift, Cassandra.java, CliClient....
# 3                                                     []
# 8                                                     []
# ...                                                  ...
# 10110                                                 []
# 10111  [[cassandra-deps-template.xml, parent-pom-temp...
# 10112                                                 []
# 10115                                                 []
# 10116                                                 []
#
# [5495 rows x 4 columns]

# %%
df_key_commit_valido_only_bugs['modified_files'] = df_key_commit_valido_only_bugs['commits'].apply(get_modified_files_from_commit)
# Out:
# <ipython-input-61-505cf831aba0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cassandra_bug_issues['commits'] = df_key_commit_valido_only_bugs['commits']
# <ipython-input-61-505cf831aba0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cassandra_bug_issues['modified_files'] = df_key_commit_valido_only_bugs['modified_files']
#                    key issue_type                                     commits  \
# 0        CASSANDRA-263        Bug  [9164940f41972e3611d1ad38a903ca39562e6feb]
# 1        CASSANDRA-262        Bug  [ef203cf00070fd719f87db9dd2384b8bc116ebd6]
# 2        CASSANDRA-261        Bug  [cdd8b170628176924c21db1cb6dcbecf4c7f2148]
# 3        CASSANDRA-260        Bug                                          []
# 8        CASSANDRA-255        Bug                                          []
# ...                ...        ...                                         ...
# 18569  CASSANDRA-18770        Bug                                         NaN
# 18570  CASSANDRA-18769        Bug                                         NaN
# 18572  CASSANDRA-18767        Bug                                         NaN
# 18573  CASSANDRA-18766        Bug                                         NaN
# 18574  CASSANDRA-18765        Bug                                         NaN
#
#                                           modified_files
# 0      [[Memtable.java, SSTableSliceIterator.java, Sl...
# 1                   [[cassandra.thrift, Cassandra.java]]
# 2      [[cassandra.thrift, Cassandra.java, CliClient....
# 3                                                     []
# 8                                                     []
# ...                                                  ...
# 18569                                                NaN
# 18570                                                NaN
# 18572                                                NaN
# 18573                                                NaN
# 18574                                                NaN
#
# [10118 rows x 4 columns]

# %%
df_cassandra_bug_issues
# Out:
#                   key issue_type  \
# 0       CASSANDRA-263        Bug
# 1       CASSANDRA-262        Bug
# 2       CASSANDRA-261        Bug
# 3       CASSANDRA-260        Bug
# 8       CASSANDRA-255        Bug
# ...               ...        ...
# 10110  CASSANDRA-9681        Bug
# 10111  CASSANDRA-9680        Bug
# 10112  CASSANDRA-9679        Bug
# 10115  CASSANDRA-9676        Bug
# 10116  CASSANDRA-9675        Bug
#
#                                                  summary    status  \
# 0       get_slice needs to support desc from last column  Resolved
# 1         get_slice needs to allow returning all columns  Resolved
# 2                         get_slice needs offset + limit  Resolved
# 3      Unable to read all columns in a column family ...  Resolved
# 8                        Supercolumn deserialization bug  Resolved
# ...                                                  ...       ...
# 10110  Memtable heap size grows and many long GC paus...  Resolved
# 10111                                 Update CQL version  Resolved
# 10112     Don't rely on client CQL export for cqlsh DESC  Resolved
# 10115  CQLSSTableWriter gives java.lang.AssertionErro...  Resolved
# 10116  BulkLoader has --transport-factory option but ...  Resolved
#
#                                           commits  \
# 0      [9164940f41972e3611d1ad38a903ca39562e6feb]
# 1      [ef203cf00070fd719f87db9dd2384b8bc116ebd6]
# 2      [cdd8b170628176924c21db1cb6dcbecf4c7f2148]
# 3                                              []
# 8                                              []
# ...                                           ...
# 10110                                          []
# 10111  [9be8369ae65be8eb4848eb9ef58e2909a8d89016]
# 10112                                          []
# 10115                                          []
# 10116                                          []
#
#                                           modified_files
# 0      [[Memtable.java, SSTableSliceIterator.java, Sl...
# 1                   [[cassandra.thrift, Cassandra.java]]
# 2      [[cassandra.thrift, Cassandra.java, CliClient....
# 3                                                     []
# 8                                                     []
# ...                                                  ...
# 10110                                                 []
# 10111  [[cassandra-deps-template.xml, parent-pom-temp...
# 10112                                                 []
# 10115                                                 []
# 10116                                                 []
#
# [5495 rows x 6 columns]

# %% [markdown]
# # Calcula a frequência dos arquivos nos issues

# %%
# @title
list_temp_key, list_issue_type, list_temp_commits, list_temp_modified_files = list(), list(), list(), list()

list_temp_commit_key = list()
for i in df_cassandra_bug_issues.index:
  consulta_commits = df_cassandra_bug_issues['commits'][i]
  if consulta_commits is not None:
    if len(consulta_commits) > 0:
      for each_commit in consulta_commits:
        #print(df_cassandra_all_issues['key'][i], df_cassandra_all_issues['commits'][i], df_cassandra_all_issues['modified_files'][i])
        if df_cassandra_bug_issues['key'][i] not in list_temp_key:
          list_temp_key.append(df_cassandra_bug_issues['key'][i])
          list_issue_type.append(df_cassandra_bug_issues['issue_type'][i])
          commits_separated_by_commas = ",".join(df_cassandra_bug_issues['commits'][i])
          list_temp_commits.append(commits_separated_by_commas)
          list_temp_modified_files.append(df_cassandra_bug_issues['modified_files'][i])
          l_temp_commits = commits_separated_by_commas.split(',')
          for e in l_temp_commits:
            elemento = (e, df_cassandra_bug_issues['key'][i])
            list_temp_commit_key.append(elemento)

dict_temp_2 = {
    'keys':list_temp_key, 'issue_type':list_issue_type, 'commits':list_temp_commits, 'modified_files':list_temp_modified_files
}

df_temp_2 = pd.DataFrame(dict_temp_2)
df_temp_2
# Out:
#                 keys issue_type  \
# 0      CASSANDRA-263        Bug
# 1      CASSANDRA-262        Bug
# 2      CASSANDRA-261        Bug
# 3      CASSANDRA-163        Bug
# 4      CASSANDRA-155        Bug
# ..               ...        ...
# 885  CASSANDRA-10000        Bug
# 886   CASSANDRA-9914        Bug
# 887   CASSANDRA-9880        Bug
# 888   CASSANDRA-9814        Bug
# 889   CASSANDRA-9680        Bug
#
#                                                commits  \
# 0             9164940f41972e3611d1ad38a903ca39562e6feb
# 1             ef203cf00070fd719f87db9dd2384b8bc116ebd6
# 2             cdd8b170628176924c21db1cb6dcbecf4c7f2148
# 3    74dcfb263ca695534ec631d8cf11f909e54a9765,af47d...
# 4    7518f7ce9f012cf5a5bbcf976a1590a1b5531db0,34630...
# ..                                                 ...
# 885           5768e5ae41879885e7e2aca79b38bed53df55711
# 886           bb36090fa0858456fb1ba80adf71fb3dc24a1aac
# 887           6c90950489a42a38a6ddfa45f79c84a110dffbe7
# 888  c1bf002234bd44bce120658e9b08b3d67901e5bb,738df...
# 889           9be8369ae65be8eb4848eb9ef58e2909a8d89016
#
#                                         modified_files
# 0    [[Memtable.java, SSTableSliceIterator.java, Sl...
# 1                 [[cassandra.thrift, Cassandra.java]]
# 2    [[cassandra.thrift, Cassandra.java, CliClient....
# 3    [[Memtable.java], [Memtable.java], [DatabaseDe...
# 4    [[ColumnFamilyStore.java, Memtable.java, Compa...
# ..                                                 ...
# 885                           [[EmptyValuesTest.java]]
# 886                 [[build.xml, KeepBriefBrief.java]]
# 887  [[Verb.java, Message.java, ReflectionUtils.jav...
# 888                         [[build.xml], [build.xml]]
# 889  [[cassandra-deps-template.xml, parent-pom-temp...
#
# [890 rows x 4 columns]

# %%
# 4. Extract Commit and Issue Data
#commits = list(RepositoryMining(github_repo_url).traverse_commits())

# Assuming you have a Jira API or library to fetch issue data
# issues = fetch_jira_issues(jira_url)

# %%
# 5. Data preparation
# Filter commits made for this repository
# repository_commits = [commit for commit in commits if commit.project_name == 'your_repository']
repository_commits = dict_commit_modified_files.keys()

# %%
# Extract modified files from each commit
#modified_files = [(commit.hash, file) for commit in repository_commits for file in commit.modifications]
modified_files = []
for k, v in dict_commit_modified_files.items():
  for each in v[1]:
    elemento = (k, each)
    modified_files.append(elemento)

# %%
len(list_temp_commit_key)
# Out:
# 1780

# %%
# Assuming you have a function to extract the issues mentioned in commits
#commit_issues = extract_issues_mentioned_in_commits(repository_commits, issues)
commit_issues = list_temp_commit_key

# %%
commit_issues
# Out:
# [('9164940f41972e3611d1ad38a903ca39562e6feb', 'CASSANDRA-263'),
#  ('ef203cf00070fd719f87db9dd2384b8bc116ebd6', 'CASSANDRA-262'),
#  ('cdd8b170628176924c21db1cb6dcbecf4c7f2148', 'CASSANDRA-261'),
#  ('74dcfb263ca695534ec631d8cf11f909e54a9765', 'CASSANDRA-163'),
#  ('af47dc8476a6e4e4856476e4acff1ac8321a6a39', 'CASSANDRA-163'),
#  ('5630eb378d927bba8eb0ccfa083436b2a2052c32', 'CASSANDRA-163'),
#  ('9f65dd42188698fe6862d42aa1540e496716089a', 'CASSANDRA-163'),
#  ('495ae9c7e78b2d5880cf74072be13d1015394abc', 'CASSANDRA-163'),
#  ('9625910a533715e24211038ddd2776f5ec74ceae', 'CASSANDRA-163'),
#  ('bd4842410e73574dff8f3a51bd95e414f76ed506', 'CASSANDRA-163'),
#  ('a23960e24a184bd0a01bf4c2bd25323ff9200b6e', 'CASSANDRA-163'),
#  ('082dedf97b4f9df77b896c65d374a9a4076364b1', 'CASSANDRA-163'),
#  ('1e09482a38cbd9bcf4d056781332f8d6e84a624b', 'CASSANDRA-163'),
#  ('963dd54b71bdcac29c484d89a826773a3f090496', 'CASSANDRA-163'),
#  ('2cf4ca3a94ff972b422f1be1a2d601d07ff31a12', 'CASSANDRA-163'),
#  ('cc672f36158c2dee3abad1fa6f51488f14ffb902', 'CASSANDRA-163'),
#  ('7d68cedecd4444537535e48074c38686ccc76f9c', 'CASSANDRA-163'),
#  ('1dff098e4c6d42b80ee05c7a444127752f112d08', 'CASSANDRA-163'),
#  ('944e3be4e34a4f9ee160e5f41275f1ad65b81fcb', 'CASSANDRA-163'),
#  ('2641424247123919d47c409b310cc00f030573fa', 'CASSANDRA-163'),
#  ('879691dd3546230690835899afb0ff0ce8905eb0', 'CASSANDRA-163'),
#  ('b24bd08616ed4b0395af5d96f27f378202bef0ee', 'CASSANDRA-163'),
#  ('9e7774ac7388837e0e67d41badfa31fe62158d2d', 'CASSANDRA-163'),
#  ('4a3ca5c70e94d6b9329b7289f61ffbe708828ebf', 'CASSANDRA-163'),
#  ('ac46747f84e62f6c9cbad0fb2e67a0eb95f43b01', 'CASSANDRA-163'),
#  ('dcde8cac0d6d96c342c6409a189edc372ddcb203', 'CASSANDRA-163'),
#  ('cba1b68dbececb2aba500d56059e99bdab058b10', 'CASSANDRA-163'),
#  ('ee9bd549e83a157ae727f2e38c921694fffda52d', 'CASSANDRA-163'),
#  ('1f65a12c33e730b9f5bd56e6c8d00ed39bc456a1', 'CASSANDRA-163'),
#  ('ca076140472bfde1209423946441f1bd5a35efc1', 'CASSANDRA-163'),
#  ('1fab099892db08a0edb4b1ad48a8ffd6b3dfd5e8', 'CASSANDRA-163'),
#  ('9bbcbf5052286b84e2a6acaf677c992f30bc1182', 'CASSANDRA-163'),
#  ('67b7c3a394453303e7b4a95988c17a4a9fd0a723', 'CASSANDRA-163'),
#  ('5de72e548faf475df60b87370d736722473fb27b', 'CASSANDRA-163'),
#  ('df014036bb720895837a44d0273ff41ebc357cba', 'CASSANDRA-163'),
#  ('5d88ff4e41210f95d0e3e53ded779765b0136c2a', 'CASSANDRA-163'),
#  ('b325316f58a4df07d8037b179fe53c03f97dfd2e', 'CASSANDRA-163'),
#  ('bdef0724352423191aaad141de5102b886d50ae1', 'CASSANDRA-163'),
#  ('5ed41ea9c6f944e5833f536ff21fbb9ed7810972', 'CASSANDRA-163'),
#  ('aeadda5bada0c32719dd74995a672a1ad7589805', 'CASSANDRA-163'),
#  ('f56244d21a331cec7da5b751a4de9effad49952b', 'CASSANDRA-163'),
#  ('93b36d4b8293d76e70c75df5d2674cb279808d5b', 'CASSANDRA-163'),
#  ('e87008bb9cd37315759623bfba0e3f8ba1eddca1', 'CASSANDRA-163'),
#  ('d06dbbbf7b733bd3141acca29a452b2da2f3502d', 'CASSANDRA-163'),
#  ('917fabe231b6bcbc754f04f92b3449a97344826b', 'CASSANDRA-163'),
#  ('35a4f7dd68019fd860b1a741674cae5bd3c6c08d', 'CASSANDRA-163'),
#  ('cc5128a02e01c3dad1f658f7dc6281e4f55eeb9a', 'CASSANDRA-163'),
#  ('08dbbd689ee7db7443c6920dfcd402710c1dd964', 'CASSANDRA-163'),
#  ('33f37f86f64a570d63c7102b11ea455ff4a4806d', 'CASSANDRA-163'),
#  ('cefaa4eb7168a63bbe5b04ad7b9bc093a34f4bb8', 'CASSANDRA-163'),
#  ('8f2a26c4f109d88a8fc1a41138de1c3d0bf39a05', 'CASSANDRA-163'),
#  ('75e858a66de48a7579fa396ea2e46326c7155f29', 'CASSANDRA-163'),
#  ('a85e731f297236f6f43ea95c3549f2d1424926fa', 'CASSANDRA-163'),
#  ('593a7257b5d5243c4ceb75b5417fb05e8a98cc90', 'CASSANDRA-163'),
#  ('f0c7a6f03cf55ddcfe11a58c80087ed8b0806cf4', 'CASSANDRA-163'),
#  ('1e35fa4b5a9afb4f37147a7a932a7892f2f450c1', 'CASSANDRA-163'),
#  ('6d06f32a7729524a195ad67ba82157e390dc3912', 'CASSANDRA-163'),
#  ('00cd9b9fff711a678c37b1f93ecd8417f22c256e', 'CASSANDRA-163'),
#  ('0db1431e33659392b11060451c71d006941a0dda', 'CASSANDRA-163'),
#  ('6af82eddff9d2923ff5447120dac432bd0dadae4', 'CASSANDRA-163'),
#  ('d9836e0efe66c0cc0e33f32b605f6920893fa7a5', 'CASSANDRA-163'),
#  ('369966a2af65aa1d8e8248307ebd187fccacbd8e', 'CASSANDRA-163'),
#  ('dbb36a476bc502708ee7443e41bba570bfd5633a', 'CASSANDRA-163'),
#  ('9b77cdea769c3009f0265ebf566415008157a172', 'CASSANDRA-163'),
#  ('233ef3403a1654763f53de3ca2f92d1c82d16cf5', 'CASSANDRA-163'),
#  ('b14236f946337cab5f78407253bd296a6f3fbb22', 'CASSANDRA-163'),
#  ('aedce5fc6ba46ca734e91190cfaaeb23ba47a846', 'CASSANDRA-163'),
#  ('6ab0c301edaf16544de7f839ffcd345dadef1cf6', 'CASSANDRA-163'),
#  ('58de86bff5e9383b679d9bb48cc95ec444275ca7', 'CASSANDRA-163'),
#  ('4047dd1213ed99b3d7bec253b551b4cae911990a', 'CASSANDRA-163'),
#  ('917068dcbfb9909b5f1695dc18e9a7b250264b42', 'CASSANDRA-163'),
#  ('a431d846c191d29d49f98c53675bffcc7956d294', 'CASSANDRA-163'),
#  ('15235ee63be2d8f39486ff97dbbdd8ed24bb9812', 'CASSANDRA-163'),
#  ('40a7e8606eed7664de07653eb962cee3fa77d72b', 'CASSANDRA-163'),
#  ('93478ab46c88d6fd198db67ed3ba25251cc30c8c', 'CASSANDRA-163'),
#  ('ed0026fed868dff61601a073b649ed8b9d5e6311', 'CASSANDRA-163'),
#  ('7b23b95fdecb9b756cff6a0884c73906e67e65dc', 'CASSANDRA-163'),
#  ('bed42c2104ebaac83da4292703c08a5c963e062c', 'CASSANDRA-163'),
#  ('8b5434f3dffabc70230d434befa79bb4881a6fe3', 'CASSANDRA-163'),
#  ('d306144282595be6818fa386a3fbb4aece040884', 'CASSANDRA-163'),
#  ('33cf701d1d6b8112b66d02416224bb782e48b287', 'CASSANDRA-163'),
#  ('4012134f6e03b61bbf5ce64cc456cf7592675d67', 'CASSANDRA-163'),
#  ('9f7ab09f733659c94e918db03d72e6a860d654b4', 'CASSANDRA-163'),
#  ('b7be1980b1b41731f27433cd80743ec76b4beab1', 'CASSANDRA-163'),
#  ('ea1d1614211b01d86d440dce8fe1a60a0bc3c7c1', 'CASSANDRA-163'),
#  ('79e1e8062703f12b5c181ccfc72fe10d293920a5', 'CASSANDRA-163'),
#  ('f5f59123769a0aa71d07b22518367d35c481d711', 'CASSANDRA-163'),
#  ('b2abcb7fc9afde553a071c4050ba4573122c2329', 'CASSANDRA-163'),
#  ('4a5c282f7615cc97929d76f36fe82e190fecbb89', 'CASSANDRA-163'),
#  ('7f9ed0ddbaabbcc94311e25b2df60415da15ede7', 'CASSANDRA-163'),
#  ('5012463b60e31c78a5a2af5e0ca78b64e4dc38a6', 'CASSANDRA-163'),
#  ('81b0acb2a9a67dd122087a00d2ec70e2b48b0a38', 'CASSANDRA-163'),
#  ('5c54f42ffa72ee940eb74ec2ee8805e4edad5eff', 'CASSANDRA-163'),
#  ('1644e82f757024df8833668e54cb75e309d9f427', 'CASSANDRA-163'),
#  ('ebd05ddbe1fca8c70e9790628c0cce47327e4708', 'CASSANDRA-163'),
#  ('a16c4fe0a5037ceb4b7b5d88efad6416a762e345', 'CASSANDRA-163'),
#  ('b2a2d46352d2dcd57cef968a8cd4a2189bea32ce', 'CASSANDRA-163'),
#  ('160e7f294591b1505059b6adcdc7bea2f9591991', 'CASSANDRA-163'),
#  ('01087489ed5484a2f7c5e7d55e8adb8bcf51b7a7', 'CASSANDRA-163'),
#  ('7d6a60ddd0e156f6028c05d97fa9179f86fe02ee', 'CASSANDRA-163'),
#  ('3ae97ba5265af4966192226de9bf4974c6ca2123', 'CASSANDRA-163'),
#  ('6c0a4626249af927077bed552533eac2e3ed16a8', 'CASSANDRA-163'),
#  ('bdbc61ff722db1ad7a0803ba82024345adb17f2a', 'CASSANDRA-163'),
#  ('aa133b70fa08039b458c3b5fc295ce3624b8d43d', 'CASSANDRA-163'),
#  ('6f55427920b53a6d915cff05c9171f328da3d9c8', 'CASSANDRA-163'),
#  ('37d81b9dcb08dd8c16a560591f46481b5d316841', 'CASSANDRA-163'),
#  ('116de2bee5920bc6842300a3f686d88f443b281d', 'CASSANDRA-163'),
#  ('86c9c00e98a1867deff3b8acc883d224b532197b', 'CASSANDRA-163'),
#  ('be9eff573342cd4993eb4fc8ee694dc885e8a8e4', 'CASSANDRA-163'),
#  ('7af9c6ac88278d34202fea922606905b326f7811', 'CASSANDRA-163'),
#  ('2b1e6aba405002ce86d5badf4223de9751bf867d', 'CASSANDRA-163'),
#  ('6eea3ea395957d1e799952de3423cc29fd469e3e', 'CASSANDRA-163'),
#  ('f970de55746dd074843d8cfd5385b12acda56ee9', 'CASSANDRA-163'),
#  ('f9b6d3dac7d60b4409f05c25e743dfbbf32a50f4', 'CASSANDRA-163'),
#  ('ae0486132e5aa7e49868aa36945829ce59067815', 'CASSANDRA-163'),
#  ('33d71b825f5d5bf924629d7e70ebe018eb9d2872', 'CASSANDRA-163'),
#  ('7f855d113bef60808dd55735e70ec86646582de1', 'CASSANDRA-163'),
#  ('3adfd1575cc3cf81397a7d148d5b2ed768b67014', 'CASSANDRA-163'),
#  ('248ea0b3459eed6283418c63c467f5bf4e487206', 'CASSANDRA-163'),
#  ('91187b542eb41ad137f1897a9c3f6c08239bf09d', 'CASSANDRA-163'),
#  ('63165a719cd8ec9d7f06c186f61d39403e192edc', 'CASSANDRA-163'),
#  ('860141229ab3291675d9b632e34ab4405359316b', 'CASSANDRA-163'),
#  ('f9c998cbc33c1cdbd65c1b57a1e3fba6c38a17a5', 'CASSANDRA-163'),
#  ('04eba90949a674cff21756ade74d9fef3f4878c5', 'CASSANDRA-163'),
#  ('173f2552d10b5d081888f62864c40380622097e7', 'CASSANDRA-163'),
#  ('f294ee12722d074006bb3a5bc72edf2b248b1d6b', 'CASSANDRA-163'),
#  ('9b10928c159317160fb3049727679a48232b6041', 'CASSANDRA-163'),
#  ('23d7a558ee824a22d382e1b645814638a2cd2985', 'CASSANDRA-163'),
#  ('6250065089b80d02d54908212d2b5f45037720f2', 'CASSANDRA-163'),
#  ('99da210229b9ddab8ce46d0664c46fe92282c6e3', 'CASSANDRA-163'),
#  ('b9a89a3accbf804807ef2887b37e50e7b89f0044', 'CASSANDRA-163'),
#  ('b0dbea3dd0bebac97ddc14a847cce54cc38a7177', 'CASSANDRA-163'),
#  ('2a9fc0e887612725a51b3822a266c1b3d3fadcaf', 'CASSANDRA-163'),
#  ('66a48e7ab137e7ec54b0bab5eaee44a9449930dd', 'CASSANDRA-163'),
#  ('49c31d68376ee9f8c0efaea1579d3d1b6253e16a', 'CASSANDRA-163'),
#  ('16b02887df63ab7c4c6ced6c28225928fbe05451', 'CASSANDRA-163'),
#  ('0022e153fa4915c0fbf83b7479b54f0809c5a272', 'CASSANDRA-163'),
#  ('30be921d44ed62f0c29a40dc841190519f84cffc', 'CASSANDRA-163'),
#  ('675a0f4713f3b25edcb6b8108ed4dc879fa0ec53', 'CASSANDRA-163'),
#  ('446e2537895c15b404a74107069a12f3fc404b15', 'CASSANDRA-163'),
#  ('c08aaabd95d4872593c29807de6ec1485cefa7fa', 'CASSANDRA-163'),
#  ('ec52e77ecde749e7c5a483b26cbd8041f2a5a33c', 'CASSANDRA-163'),
#  ('07bb8f98e07f10308d65c264fe29f8c5ee8d4f4f', 'CASSANDRA-163'),
#  ('514dcd944c400a8a540962f54e16561d56496425', 'CASSANDRA-163'),
#  ('7c5fc40b8b644e05c32479f2581309f75f981421', 'CASSANDRA-163'),
#  ('94be12c6fdfe48f042f63c1b5985ec59f772f005', 'CASSANDRA-163'),
#  ('f32cff8e1fb69317219ffaee81b5861a54b83a1b', 'CASSANDRA-163'),
#  ('42ea6e1f3751845bd0d1326ab789a53a20783a53', 'CASSANDRA-163'),
#  ('55a736acff1bfae779c6f01b2280ef50befca1a5', 'CASSANDRA-163'),
#  ('947edf1f19a8798b4befd9d598f3e17bbf3d7e48', 'CASSANDRA-163'),
#  ('a384faaa8aa2c5f0f313011a30ef64e7e795ab1e', 'CASSANDRA-163'),
#  ('d6c37bdd18b2632ea9093f2422a0cfa723e36b96', 'CASSANDRA-163'),
#  ('628394a6fad134dee3d1ec340b88ffcba51e67e7', 'CASSANDRA-163'),
#  ('5aaa5cad6eed26f6a20ef586e615192bfeca9cc1', 'CASSANDRA-163'),
#  ('353d4a052c866cb230e06e69e99d9c5c8c8d955c', 'CASSANDRA-163'),
#  ('6092b01e329246fc524400aaced63c82d55e017a', 'CASSANDRA-163'),
#  ('8c8103cae53a62251d1d345bf88fd001cdefb92c', 'CASSANDRA-163'),
#  ('98ac45a8a43566311bb760f1275f2a7b2bbe0766', 'CASSANDRA-163'),
#  ('61aeb910930faa6caeac98a184e1909e69d7abb0', 'CASSANDRA-163'),
#  ('87c6daf6e3d64b532bcdca09f6de22c3b6f56bf7', 'CASSANDRA-163'),
#  ('452d6a445a6935d3e7d0e0fdf59e87d2a2ff95e7', 'CASSANDRA-163'),
#  ('30df089d72d7d9889eebacd8c00537e46a2bcaab', 'CASSANDRA-163'),
#  ('08f4f5a67439c50a3313b51e63c38b7469c33a0b', 'CASSANDRA-163'),
#  ('52dbc3f1ba7a97654c305f4f9c4af008b450e9b0', 'CASSANDRA-163'),
#  ('87ea6bc9138a4354ccdd2860463cec3e0e55e90f', 'CASSANDRA-163'),
#  ('5ba79cbf208649d36ba04834fc8ef242638dee7e', 'CASSANDRA-163'),
#  ('052222615a754e5bbb5299d51470a2ccdb70a5b0', 'CASSANDRA-163'),
#  ('4c12f1961b1a84f37c3eab8fc83a8640693d5665', 'CASSANDRA-163'),
#  ('ffc7745cfbd12624653092b01f2e08b0f9332875', 'CASSANDRA-163'),
#  ('5250d7ffd2df9e75219ce5a544ae0209ba3446a4', 'CASSANDRA-163'),
#  ('43c3ab44573dee5fd099895146f4a008b54901f6', 'CASSANDRA-163'),
#  ('2b99b5d3542f8695e419e851c2f07758ef46373d', 'CASSANDRA-163'),
#  ('f60e4ad4298725dac57c36da8427d992be19eb8a', 'CASSANDRA-163'),
#  ('9dc8c2198045442ef011f19c6736fdb09862c439', 'CASSANDRA-163'),
#  ('074452efab39bd86ac8510e4d50a829b0b4e749f', 'CASSANDRA-163'),
#  ('77a6090b24520bfa06e935783358e58fa1c37f1b', 'CASSANDRA-163'),
#  ('172a9754d62559984b325babd6902ae78c9f6891', 'CASSANDRA-163'),
#  ('2457599427d361314dce4833abeb5cd4915d0b06', 'CASSANDRA-163'),
#  ('2b0a8f6bdac621badabcb9921c077260f2470c26', 'CASSANDRA-163'),
#  ('99decd8eface9cd38ddd70542aa28a2773810526', 'CASSANDRA-163'),
#  ('5786b3204d6da352124338c0130451e27dd056b0', 'CASSANDRA-163'),
#  ('5790b4a44ba85e7e8ece64613d9e6a1b737a6cde', 'CASSANDRA-163'),
#  ('7a6c3272e3bb6b69ec55bb362ddad5978b4fb35f', 'CASSANDRA-163'),
#  ('e338d2fa8ba1eeb085290612559ab6782fecdd1d', 'CASSANDRA-163'),
#  ('639d4b240c084900b6589222a0984babfc1890b1', 'CASSANDRA-163'),
#  ('a59be2693e33e899264bc29b37b669d4bb645a74', 'CASSANDRA-163'),
#  ('a7f41345ac71826574d09d56ebd402d0ddc3ea3f', 'CASSANDRA-163'),
#  ('ae179e45327a133248c06019f87615c9cf69f643', 'CASSANDRA-163'),
#  ('878d6164278257fae05adba7402d849b7735162e', 'CASSANDRA-163'),
#  ('fb34b7950483abc5a15c09e802852183699c0ecb', 'CASSANDRA-163'),
#  ('5f4cc45cdb9c4da3bd78c1714738dd39b4768ace', 'CASSANDRA-163'),
#  ('33e3af59f9521f7d3e9ddccdd107a05d1c6fb939', 'CASSANDRA-163'),
#  ('df3b6027bc90c658963e7bf72933b1507c6c6beb', 'CASSANDRA-163'),
#  ('43139f8668e0a524035507efc619cd0e0f06cea9', 'CASSANDRA-163'),
#  ('b724d1ea5139140935b56fd8397d85419ed85408', 'CASSANDRA-163'),
#  ('5a54d9a6240daa9e58dde702245f574002a42783', 'CASSANDRA-163'),
#  ('e37d577b6cfc2d3e11252cef87ab9ebba72e1d52', 'CASSANDRA-163'),
#  ('e58b7df935cfd1f12560fb174eebda2ff529f9e8', 'CASSANDRA-163'),
#  ('6aa83990530dbfe5e8a2c3a194c4dcbb3ffd4b59', 'CASSANDRA-163'),
#  ('028df729b7bc0f63359990d9cc7ebb7d653232d5', 'CASSANDRA-163'),
#  ('bd7d1198ac1e02785e912c7cfbb504ddaab6bb93', 'CASSANDRA-163'),
#  ('90e0013126e4875d696891c67d1b22fdb2b8ba7a', 'CASSANDRA-163'),
#  ('20f12e97446eee55461a8d3512a94389a67e79ee', 'CASSANDRA-163'),
#  ('ace28c9283358da75538c4e2250f8437efb7168f', 'CASSANDRA-163'),
#  ('ed4fad19ecd9b02892623ffd538c0c45dcdc5a56', 'CASSANDRA-163'),
#  ('34193ee7666a7521922993ed41407c61832822d0', 'CASSANDRA-163'),
#  ('489a9e8fa91ab6680b2a3857ed4e97f7cf2677ba', 'CASSANDRA-163'),
#  ('98a08ebcf11a5124ddf865b5337c781a11377588', 'CASSANDRA-163'),
#  ('e98be186d1e39c45aa34e6ea995f0bf718b99015', 'CASSANDRA-163'),
#  ('1a9286c07a5c168df677da9d6be7178d087ea005', 'CASSANDRA-163'),
#  ('0997ad6fff9896df34ba1e3425559f689d96933b', 'CASSANDRA-163'),
#  ('6c723101f7b068c3fa119e2dd393460835aaa8cf', 'CASSANDRA-163'),
#  ('0be8cb665248982ea9a1f773d845cea926dd683f', 'CASSANDRA-163'),
#  ('9a6ee93f63301d03ff1d20032e6d80f806a14d5d', 'CASSANDRA-163'),
#  ('23826f7a26f8fb662d78c5ec9976a89c57d8ac9f', 'CASSANDRA-163'),
#  ('507ed148408b113aa5b4e306bc512a0dcbb5e4f8', 'CASSANDRA-163'),
#  ('f53aacba80de3c3441e1524be9498f6d15c5c411', 'CASSANDRA-163'),
#  ('ee186b6b05569537eb979027176ccee57354c4da', 'CASSANDRA-163'),
#  ('17042f19b084d93bd3bcc35c7282812f456b7640', 'CASSANDRA-163'),
#  ('d0e8ba4947d3e7804421869bcd1997ca6aad3840', 'CASSANDRA-163'),
#  ('842f1509d46bf068abca1e064f23454892347e60', 'CASSANDRA-163'),
#  ('c5158e53e8ac9386603f607c67ec7fbaa827c5ae', 'CASSANDRA-163'),
#  ('a7895cfb2cdc667041402648bf922265cb0d34c3', 'CASSANDRA-163'),
#  ('b22ad4210cbf9c0c0bd6e595265b162f391da3a1', 'CASSANDRA-163'),
#  ('3b46e5bda61c0944ec28d56c289954d9f34c418e', 'CASSANDRA-163'),
#  ('a3a8dbca5cc190caea36c5029d83f02977b6d149', 'CASSANDRA-163'),
#  ('4e3555c1d99b6a3273262443befffe73f86c203d', 'CASSANDRA-163'),
#  ('aeee9f74d9095a802a23f1a47be021ede6fb65bc', 'CASSANDRA-163'),
#  ('106b1cdabe90bd28e8b6accac232746dc023987c', 'CASSANDRA-163'),
#  ('bd46463fbb7d6b0998c837450ce61df13eda041d', 'CASSANDRA-163'),
#  ('2d825a18165751badbccced7eaa8dc09ef139e75', 'CASSANDRA-163'),
#  ('609497471441273367013c09a1e0e1c990726ec7', 'CASSANDRA-163'),
#  ('1492be07cdf12afbba662645365cb991f223443d', 'CASSANDRA-163'),
#  ('2ca7599023a1e507f263b0c4854ab26b3ba283ac', 'CASSANDRA-163'),
#  ('05ccdc6411b9d3388a74ba06d1ce153d33ffe1c3', 'CASSANDRA-163'),
#  ('4a94f75b0177cab18539317c3f58db2014091a9b', 'CASSANDRA-163'),
#  ('f8fc0311b65b3d82737352f3d01483c0334a6867', 'CASSANDRA-163'),
#  ('2af4fba7e586b17f9e7bc54b761ef2909d690b12', 'CASSANDRA-163'),
#  ('f6deca3db2ec173c8d0b2cd33ef2660012ae3f69', 'CASSANDRA-163'),
#  ('99880d22de0023081a6d5829bef991eb96f7c342', 'CASSANDRA-163'),
#  ('7c3966bfe3d42daf97fb3b551060958d1c9c017a', 'CASSANDRA-163'),
#  ('c20566fa64031dd30a1f731eee1394264977eb6f', 'CASSANDRA-163'),
#  ('8287ebcb6ad46529ca90600dc0c2f98ecab89cf0', 'CASSANDRA-163'),
#  ('e4eabd901522742550074d5c3c5f25b642037891', 'CASSANDRA-163'),
#  ('6d6d1890425e0372debc3acc21f86dce7c08cf37', 'CASSANDRA-163'),
#  ('e739f60570aaeb7cd8194c8cbed4bbe1ea9ca006', 'CASSANDRA-163'),
#  ('6f067af5157be9ed8df566d0a5df042c694215e2', 'CASSANDRA-163'),
#  ('c9c9c42263f1d477e45e9c2053bc1bbedc08bf8e', 'CASSANDRA-163'),
#  ('21448c50891642f95097a9e5ed0a3802bd90a877', 'CASSANDRA-163'),
#  ('87fdc9b667d68602ccb9d0ef27233d801b600cae', 'CASSANDRA-163'),
#  ('1e92ce43a5a730f81d3f6cfd72e7f4b126db788a', 'CASSANDRA-163'),
#  ('483c745334619ff19df8469f565b5346e7b2a5d0', 'CASSANDRA-163'),
#  ('411c56014d3eb8fdd001c2381c376c968cdef499', 'CASSANDRA-163'),
#  ('85cc390189f45be54dec9b146f66eeb7737fb0eb', 'CASSANDRA-163'),
#  ('6c445d6b7f3c8933a0bfd599ba8455b7254a323d', 'CASSANDRA-163'),
#  ('d43b9ce5092f8879a1a66afebab74d86e9e127fb', 'CASSANDRA-163'),
#  ('25580e3a7f4bc01aa914a713ada45c50a45d0993', 'CASSANDRA-163'),
#  ('0eab80bf389114be8d6f7627f72249bbc3c02e64', 'CASSANDRA-163'),
#  ('2e59ea8c7f21cb11b7ce71a5cdf303a8ed453bc0', 'CASSANDRA-163'),
#  ('6b16b67cd4dbf8633e58c1950ced3626ff7ac92b', 'CASSANDRA-163'),
#  ('7518f7ce9f012cf5a5bbcf976a1590a1b5531db0', 'CASSANDRA-155'),
#  ('34630f6447c188ca02ecb8276c5fcc6a505f75fa', 'CASSANDRA-155'),
#  ('ebefb77c6e8a5046a8c1b1bb0edd258aaf0ad8b7', 'CASSANDRA-155'),
#  ('08df0b8604cd34c4f1fb384f9f6eaba86203d116', 'CASSANDRA-155'),
#  ('c06244916ad3b3527345f4a6b6130214ddc987fb', 'CASSANDRA-155'),
#  ('a2b12784fe3785fe96d9c0e2d7e8c72bfc88ac7c', 'CASSANDRA-155'),
#  ('34207f0a92e784322743e1fd2f04234d1fbdd2f7', 'CASSANDRA-151'),
#  ('f92915ffd53348415b848ba27729caffd917dbd3', 'CASSANDRA-151'),
#  ('f5a4a1dfc5f708141209a4e15d51f82da3217a42', 'CASSANDRA-151'),
#  ('b44abadafb5e54e579c2e726036ca07c8f74b3f4', 'CASSANDRA-151'),
#  ('06699d47b62d8af8dbb60481ab36e5ed1805e0a0', 'CASSANDRA-151'),
#  ('93b0b062c2e6eaa36dda8a99da196d64e5c13871', 'CASSANDRA-150'),
#  ('7dbbca6698fdd14bae1de4a8a53a44ce21723434', 'CASSANDRA-150'),
#  ('d5eaa4e141ea830bbbacc7c249198e58169882e7', 'CASSANDRA-150'),
#  ('e2df26b899d07edbacedd0a6722bc940fc48b65b', 'CASSANDRA-150'),
#  ('d4a8f07cd81d19c7146093ce89cb54291872414a', 'CASSANDRA-149'),
#  ('e659b06f3a500a5b8a4faee5e132946c82679281', 'CASSANDRA-149'),
#  ('6d070498beeba4d431a09043fd83abb96f5eff9d', 'CASSANDRA-141'),
#  ('eb775fe7c225699a8ea61901b6dc887716780909', 'CASSANDRA-141'),
#  ('294bfa9a2106feeb5ad94ef0819001a7ca05e292', 'CASSANDRA-129'),
#  ('8edf6a6192ca201e5c2ef84452a21b8de2b953df', 'CASSANDRA-129'),
#  ('bf911cc6a852f9ef068318a3545611d9daa5112c', 'CASSANDRA-129'),
#  ('32dc02cad64bd557808a639d9430c1a8ba9afedc', 'CASSANDRA-126'),
#  ('681efb6ce7f3fcc258ceac8f8f10ebed56f85714', 'CASSANDRA-126'),
#  ('60839fea8577a135b623c3dcc002351137c7fb45', 'CASSANDRA-125'),
#  ('aee70135ef001ee13d3aa3f3da5e0d1da7183699', 'CASSANDRA-124'),
#  ('778f1dec9b90d22b6b27b8268b404ff65cd7eb8e', 'CASSANDRA-124'),
#  ('1d0cf136f6871730c663db143ada9a9b66034286', 'CASSANDRA-122'),
#  ('5dc8ba837a706be7f4f8e180b9bafdb61aa4ccac', 'CASSANDRA-122'),
#  ('39982f3649705623edb8593c7b6cb5665c156f48', 'CASSANDRA-114'),
#  ('5aad64a699602166413a6bf2f0599c1523cd55ce', 'CASSANDRA-114'),
#  ('71b3b3c7364445ed508a8ee52050ca39b9c5de66', 'CASSANDRA-109'),
#  ('1e8685d836fee9f65f976d4587da88bda3dbeca2', 'CASSANDRA-109'),
#  ('3558e45ab6758072c84272e185f2755e885798e1', 'CASSANDRA-109'),
#  ('cbf0436181fe1f47eff98f54aa161dd5fbca0479', 'CASSANDRA-109'),
#  ('ab392a6ee7db31fe7a4cf8093e7308057cd47493', 'CASSANDRA-100'),
#  ('23b1c52498a00c27cf5c5124241555aad7127966', 'CASSANDRA-100'),
#  ('d4eaf3cab3ba5726503934a6c5b026aae399aa04', 'CASSANDRA-100'),
#  ('3448ca57f3714521b5b7fc88fac43e31d0adcafa', 'CASSANDRA-100'),
#  ('86abfe10279ce957e3dad221b2ca6e58eea1758d', 'CASSANDRA-98'),
#  ('56008de4596c6885a12a22798a0fe777eb592aff', 'CASSANDRA-98'),
#  ('b224e58cb6b44f98ec0f0e69fcc3833f60e962ce', 'CASSANDRA-98'),
#  ('eb49a18acd7886b33467a71c765534066a73fdcf', 'CASSANDRA-92'),
#  ('58202a8ef364c7e1b35eedd1270c5e72d305e23c', 'CASSANDRA-92'),
#  ('becb0b1c7ab966572843da6ddbe665ef3c107e65', 'CASSANDRA-91'),
#  ('4a0378eb85397c9ff6a9cf2e85cd97f74cbb30bd', 'CASSANDRA-91'),
#  ('ece6e6d4592ff68e8153770160d3c8e20a058591', 'CASSANDRA-91'),
#  ('d1a8e1322fd5580e4e4b1178257057718ee1209c', 'CASSANDRA-91'),
#  ('02a569e384b37f17049c3d2799738a3be1f556f2', 'CASSANDRA-91'),
#  ('103a13c68f4deaaf1306b3ce7e371b7197c3bfb9', 'CASSANDRA-91'),
#  ('5e9b35cc8c056cbc36516f679fbd01314598675b', 'CASSANDRA-91'),
#  ('735435be69a03a3c4506b50facd771316e1b355c', 'CASSANDRA-91'),
#  ('cbac7af793f8a726f051d6dbf36a382fac595c45', 'CASSANDRA-91'),
#  ('568933f5c4f7bf7e373663a414dd890cdc93ec2b', 'CASSANDRA-90'),
#  ('8eccb80a317082897dc04d033fce500ac43e70aa', 'CASSANDRA-90'),
#  ('aa8290f314f183d61af50fd5335fc3e1e8294c1d', 'CASSANDRA-87'),
#  ('020d517ef4f7d8e6e475aba01acaf23c2fd32f3c', 'CASSANDRA-87'),
#  ('45e1d5188c42dd0220a51af1b574af3c4d8378ea', 'CASSANDRA-87'),
#  ('7108f3ed318f3be0afaf4bed109226d3373215c2', 'CASSANDRA-87'),
#  ('d49113fad1bf7a15ca052156b872b9bdc01b6d73', 'CASSANDRA-87'),
#  ('cf84ea718f84da3071cce0e66d6a9dc753ea4952', 'CASSANDRA-87'),
#  ('6c4b774686b3424ce84f7de51c56c86d95c85d4c', 'CASSANDRA-87'),
#  ('bb464c1f3703fc8b31be7859ca32e83e755a60dd', 'CASSANDRA-86'),
#  ('8b81c8f2fb93a051fbd317c03af727ab919034f2', 'CASSANDRA-86'),
#  ('ec9ee934382ee562eb2fabd7f5e94f7d133d79b6', 'CASSANDRA-84'),
#  ('5850178cb99dbd1e5e5333442c85470386ec1b4f', 'CASSANDRA-84'),
#  ('5fd4ff77472ffd2d20c22b801d1c8d6ad37138f8', 'CASSANDRA-82'),
#  ('12cbf7528031b6802ece8ffb1cd3b24daceb5468', 'CASSANDRA-82'),
#  ('39d97f389207d4a294750ae4ff975682fc5b47e2', 'CASSANDRA-82'),
#  ('a2899de1374fc084364184cb97eeb9526f7ddf47', 'CASSANDRA-82'),
#  ('007df950fc9e9fad255167db74517095a8326f25', 'CASSANDRA-81'),
#  ('4f4aa4fb9ea5a9bf075c0035c442005e41385532', 'CASSANDRA-81'),
#  ('0a969449fb818d0641c84f6e14634fba307084a5', 'CASSANDRA-81'),
#  ('ac414f9a52f9ffb023cf3690cd782e4ecb976140', 'CASSANDRA-78'),
#  ('425e524ab75cdaededb74703b03fb3223ba50f3d', 'CASSANDRA-78'),
#  ('cee37599f6526b9a33df3d2d8d9d87315af0f7c5', 'CASSANDRA-76'),
#  ('ceb4a10808a25fa7b9a20ad113242e8c4ab6ad76', 'CASSANDRA-76'),
#  ('449a444c7d1cfa13e1a7d25865227e1ba8c300e2', 'CASSANDRA-72'),
#  ('8a9c25ae0e849409a752b4d6eaf5a9bfbb3b3ca0', 'CASSANDRA-72'),
#  ('ddf00a509a4793bc69bf11cf10cc8155a9371f2d', 'CASSANDRA-72'),
#  ('7cad51ffd9b394895457206fc3798d468e543c8f', 'CASSANDRA-72'),
#  ('2deee7a4e70c3e17344f7bbd53e9a72a8ac99dba', 'CASSANDRA-72'),
#  ('07330c1cfa4fb83a0f7d455d01858cec90b66c21', 'CASSANDRA-68'),
#  ('88b0ee7be461abf54236eda862920e9f006b9855', 'CASSANDRA-68'),
#  ('d748648b235bd7dc95bfb2672ee156e0eb132bd8', 'CASSANDRA-68'),
#  ('850e86544004bdddd31fd63d62525412e1f47ce7', 'CASSANDRA-67'),
#  ('dc794169b8ffdce004036568619bd27b590ee1b9', 'CASSANDRA-67'),
#  ('5ed5464e31f71ef36927cd7c45c5d57632361151', 'CASSANDRA-64'),
#  ('67deae8e40edd3325028cffba70ada621e9193f9', 'CASSANDRA-59'),
#  ('cf01ea1c49f1168292cca9faa860617ab973334e', 'CASSANDRA-57'),
#  ('8d4b161f09445357a0ce5ea8b874ec31032b9bbe', 'CASSANDRA-56'),
#  ('d29e344399986f5e1b19d65811f1fa9b0d1563d4', 'CASSANDRA-37'),
#  ('46f43cee7297e267d76b3369c2aa2f1bfc76f70c', 'CASSANDRA-37'),
#  ('814bd325e55879d93f86c97189893581208556f5', 'CASSANDRA-37'),
#  ('58225374f426b2f76712eb47ef888f76f07f1121', 'CASSANDRA-19'),
#  ('94262c43908904303610c1243531a00167c03e0f', 'CASSANDRA-19'),
#  ('62642fa97e4a1bd4f3b9d253dd939da61ac2740f', 'CASSANDRA-19'),
#  ('eeb0d4c90198b14113ee094587cf0eacceb2b96f', 'CASSANDRA-19'),
#  ('4fc417c404aab0713a7d9747d22ce7eceb777859', 'CASSANDRA-19'),
#  ('a4e108c40b234fa754a56a21b63635b83f90aceb', 'CASSANDRA-19'),
#  ('0e272c233d050961fe79b94f333668b900d4fbbe', 'CASSANDRA-19'),
#  ('2a6e0714a793b546ed0ab2b59fd4239dfc27c396', 'CASSANDRA-19'),
#  ('ef6f0238ef5dbb439e85ee3c8988319c375e65df', 'CASSANDRA-14'),
#  ('eb92a9fca76f51c91c9eebaddfd439897a14a6e0', 'CASSANDRA-14'),
#  ('0dd39c6a556a8e98c946855d7dc3dbfd110d1ec9', 'CASSANDRA-14'),
#  ('110a132b18f006c4c9ca0c5913cbe64c5d3e01f7', 'CASSANDRA-14'),
#  ('73eb68c516a291e2f8a816abab20b67999eb851b', 'CASSANDRA-14'),
#  ('7e71d01a036fc0338b0f5ad1b9d61792ed190caa', 'CASSANDRA-14'),
#  ('76adf0e12ed91ee7c75164872202bff29a2ad7f4', 'CASSANDRA-14'),
#  ('478ba67b49496b2656f53671559612eac861190f', 'CASSANDRA-13'),
#  ('2f99e71f304b3663f2cc7d8bb79172a999525062', 'CASSANDRA-13'),
#  ('1a0aaf04986155eae45b2685d234b928866b681c', 'CASSANDRA-13'),
#  ('0947fb8a91ddbf9785a675bafaac51c02dd1f27e', 'CASSANDRA-13'),
#  ('bc83a65a616ca2f7b995cd4bea12729c03acee33', 'CASSANDRA-7'),
#  ('23893ead557989bb74d699e1028c9c6a1b689f3b', 'CASSANDRA-7'),
#  ('c9cef44a1a6c10036200f410c8a26942e64c8f12', 'CASSANDRA-7'),
#  ('9da949bbeed9d924f98e7cc977e864162caba2c9', 'CASSANDRA-7'),
#  ('e32423159d9b31131cc95bccfcfa6b5dabbc070a', 'CASSANDRA-7'),
#  ('e916dff8ba032d878ad4435eb7175c6a56f79ef4', 'CASSANDRA-7'),
#  ('0368e97ee4a807cb832a90c590ae5c65a98730c1', 'CASSANDRA-7'),
#  ('8380b2412e52f5a83787f8f6dd905653647464c7', 'CASSANDRA-512'),
#  ('f30ca092fc96ea0e50d0a3301bd2e848c143ca5b', 'CASSANDRA-512'),
#  ('d274cc82488f26ec19357f15144017b5e1bb7983', 'CASSANDRA-512'),
#  ('e3a88b9f80ea9ba59cf3da8f7b5cc81ccb32e24a', 'CASSANDRA-512'),
#  ('0932ed670c66ca2f8c5dc1450b85590738b773c9', 'CASSANDRA-512'),
#  ('6065d714a1fa775547dd04ab3c0fdcfdd1354755', 'CASSANDRA-509'),
#  ('65a46265df79593c684efceba0ebb93e37339e0e', 'CASSANDRA-509'),
#  ('e3dd88a8cd49a86ef37b9c4204e87bf8e47aefb7', 'CASSANDRA-509'),
#  ('baf524fe4349bfbf841e8b59ff93e142468c4b15', 'CASSANDRA-509'),
#  ('a123e984c3236b2a188411cad5c29f16e662c369', 'CASSANDRA-509'),
#  ('6528fbf250fdd2c75c8f9464e279628234a5fef4', 'CASSANDRA-509'),
#  ('944a2a1338a3c027d2ec9bae6da95a112f694db3', 'CASSANDRA-507'),
#  ('ca72d17210dd954c1c74f89873fdb47ca719da00', 'CASSANDRA-507'),
#  ('b22c91127fc5c345e72c77e7f07c425c60bcd5e6', 'CASSANDRA-507'),
#  ('05bacaeabc96a6d85fbf908dce8474acffcab730', 'CASSANDRA-507'),
#  ('d48c797f77adf62a7f7365808273edfcbe61cf33', 'CASSANDRA-507'),
#  ('d002c7edc58b3a01e57392eb4f5aab367b1a5512', 'CASSANDRA-507'),
#  ('70e1ee304c8b92c50e014944cf5955b438352c24', 'CASSANDRA-493'),
#  ('0e276b5ab0eacfdd4c96d101cf76a0ae7dde4113', 'CASSANDRA-493'),
#  ('ca4a07e4f0cc7a7e240860b8dd47d7a2082cd995', 'CASSANDRA-493'),
#  ('b42feea6432905946083e0e287b3545a5799e4a7', 'CASSANDRA-493'),
#  ('167380fb0d7fa3fc6dc9879c839419babaea2a16', 'CASSANDRA-493'),
#  ('b40af751144c1859d3a866195a92ad3ecdd35b63', 'CASSANDRA-480'),
#  ('2884f888e62dcaee42a09345614998302e3388e6', 'CASSANDRA-480'),
#  ('b074955936a0e4779aacfb380bad2c8aabddc11f', 'CASSANDRA-480'),
#  ('0e55e9ff6695504c4698115d8856620b752cf713', 'CASSANDRA-480'),
#  ('12efa878b8d7fd042c39f7c5578af0ca1120d3c7', 'CASSANDRA-479'),
#  ('38ee5fcecd6aafbef7108c00ff555af240dce823', 'CASSANDRA-471'),
#  ('2d7132069c3f8cbea3b8cef187abce10059677f8', 'CASSANDRA-471'),
#  ('a462083fc4f74e508ee0e5234c7bc34a6bdb618e', 'CASSANDRA-471'),
#  ('74258e2dc1a9720c4de172d9d2342d552f7ac3f7', 'CASSANDRA-471'),
#  ('c1b5c270df35bd9554d565c44cd409ec9d96b44f', 'CASSANDRA-471'),
#  ('7c05b897cbd81769bf5b3b33b53903f31aac09aa', 'CASSANDRA-471'),
#  ('77879d5b0633e822371df750e524b400304e65b0', 'CASSANDRA-462'),
#  ('c52be53daf74ebe74aec9d9a4658b1b686e3fda3', 'CASSANDRA-462'),
#  ('f2413f7e34aab3ead05fe16ef3cdbe1c79ca73a4', 'CASSANDRA-462'),
#  ('20793b069f553c60f0e2c8874f4ae884ea87ea6b', 'CASSANDRA-462'),
#  ('b7a529606e6123e332cb8561f0765056963d8b32', 'CASSANDRA-461'),
#  ('79f6512106885401dcb1016fcd0d0153c16b6528', 'CASSANDRA-461'),
#  ('ebfb5244dbb85746ee31ecc4679a84afbee32764', 'CASSANDRA-461'),
#  ('2e74d924898369462b01049d17fe816f52040e3b', 'CASSANDRA-461'),
#  ('6f00a24296179b0abc9673c94f76d1e551ebdeab', 'CASSANDRA-452'),
#  ('102e9119b8f9cad55ac84bb65cf0d620b3e17533', 'CASSANDRA-452'),
#  ('ea05f5baf21519b03e8ddd4dbdbb8a0ef852f45a', 'CASSANDRA-452'),
#  ('359d566e81202225886308040361ab369d1e73d9', 'CASSANDRA-452'),
#  ('58eebc9a977ef7dfafe6ea568cece963191598ce', 'CASSANDRA-452'),
#  ('fbe19b8ad7cd01f810109731b64acaaa4edf8db2', 'CASSANDRA-452'),
#  ('3e574a962c43af699eccd968b1488f724d78d5a0', 'CASSANDRA-449'),
#  ('765d1e97ff7dbe50ce13297993720147ddb6eca0', 'CASSANDRA-449'),
#  ('b38bec79cf9b9221c7db0b5602ce57c382ff1852', 'CASSANDRA-449'),
#  ('9d7bb1e0c27fd5076afc750150ab4b86f228efb5', 'CASSANDRA-449'),
#  ('82d843bad887b2858c94f559d66a55bce37fc3a9', 'CASSANDRA-448'),
#  ('36f21781965b1cc947ac7488d5e3cddd58090729', 'CASSANDRA-448'),
#  ('37e9bce381b9daf8e544db475e1a31d70e471e7b', 'CASSANDRA-448'),
#  ('e0f5809386760f29147ccc16910dfe4ad83e1c31', 'CASSANDRA-440'),
#  ('703bd684ca79f817392acfed5c26ad0871660735', 'CASSANDRA-440'),
#  ('a0d6ed1290540673b0336418cbca0dd2f07e64a8', 'CASSANDRA-440'),
#  ('3529ac711e5588918afcc8b514aa03c67a9adac7', 'CASSANDRA-440'),
#  ('a886e34909c313a1c3fa5dff48b77f1cee2c6847', 'CASSANDRA-440'),
#  ('ea10f851ba535b81456ea9ba98e50a4e2c87cf98', 'CASSANDRA-431'),
#  ('08878e90abdf774315fe8580d87611f2eaa416c2', 'CASSANDRA-431'),
#  ('8896a70b015102c212d0a27ed1f4e1f0fabe85c4', 'CASSANDRA-431'),
#  ('51fa96187c5fb0383cdfbcde5047f11803440263', 'CASSANDRA-430'),
#  ('1ea5059fe3976ce8f660b46520859c31bb433fda', 'CASSANDRA-430'),
#  ('050752c70360fe8cae9803f3db15dad2fec224fc', 'CASSANDRA-428'),
#  ('2e2dd48ff911a84ef46dae3fe05331ce8f669791', 'CASSANDRA-428'),
#  ('5da5bf9ae5e9e0fe315c88ce9168125a891363d3', 'CASSANDRA-427'),
#  ('401b46bb3c5c27717d6f64af3aab349817485322', 'CASSANDRA-427'),
#  ('c8dcc7515e9f1d7f73f2d5e6651862a1b1023bea', 'CASSANDRA-427'),
#  ('6ede8c5d91f334ff0e06197a3d1fbc4ec9480137', 'CASSANDRA-421'),
#  ('83ed1cbda98bec659fdf8ffb7e19789c04e36763', 'CASSANDRA-421'),
#  ('82b920b66e7bb551856551838e228adad043a685', 'CASSANDRA-421'),
#  ('2b8c1cec9ac40273a1491ebd697caf8431dc83a2', 'CASSANDRA-417'),
#  ('c5864a524e11842a75ac1d6c79ed137fadcb6c0e', 'CASSANDRA-417'),
#  ('37010e9d75c695d9e538873dadc3984e11eb3b25', 'CASSANDRA-417'),
#  ('8f85a51e643c904ab4f80ba98234dcb1e384dd40', 'CASSANDRA-413'),
#  ('db7759a2cac76d86a9f5b1ca82f7e08cc358c28d', 'CASSANDRA-413'),
#  ('f170a9dfadbab924996e4ecaf1bf16f6a2f1bf10', 'CASSANDRA-411'),
#  ('42ceccb90cdf10ea457c14e17344e8d7e9128bc7', 'CASSANDRA-411'),
#  ('86063aa2087b5b0bb9eff6458b528f74a39eaf02', 'CASSANDRA-411'),
#  ('03b4c2794c4c0f5e11ec9a24b52b523d8746fbb5', 'CASSANDRA-411'),
#  ('e4b3d403f3a2885dcf45ac574c9e4875f91a9724', 'CASSANDRA-411'),
#  ('d4744e178df071dbffe74499335d8ca6fd7c395e', 'CASSANDRA-411'),
#  ('1794fbed23a83abb7c6285ecb69628f90382686f', 'CASSANDRA-410'),
#  ('5632a56c469ca49d43842a399de687e47f9be1db', 'CASSANDRA-410'),
#  ('df6983bbad7f004aac52cfe78c5fb41e8a3871bc', 'CASSANDRA-410'),
#  ('89ab670eb54fe267afa83a56f9d90bb4cd10b9e5', 'CASSANDRA-410'),
#  ('5f8ce62b283a08cf284b07f647c04896970a026a', 'CASSANDRA-410'),
#  ('242fa0231bd74fe09454e67c10a4af651dd8c4e2', 'CASSANDRA-409'),
#  ('3678daa0be6e88821b3a61e20c78493d6f119449', 'CASSANDRA-409'),
#  ('46e5f23e1bb6cf374d0d89ecff40c84a1824b998', 'CASSANDRA-409'),
#  ('27ccc433f36f99ce42f3dd2463d2248f398fb19e', 'CASSANDRA-409'),
#  ('31e669ab425759b8a6e5c09a1d6635d013b838d9', 'CASSANDRA-409'),
#  ('2fe8133bbe71d186ef43aeaa3b5a320685441d68', 'CASSANDRA-409'),
#  ('45e6d912cca3de66a3af02e9df2c3484992d0a2e', 'CASSANDRA-409'),
#  ('6fdad7fd0e8c887dcaebd07b5ee274a3886b1976', 'CASSANDRA-306'),
#  ('35668435090eb47cf8c5e704243510b6cee35a7b', 'CASSANDRA-306'),
#  ('f283ed29814403bde6350a2598cdd6e2c8b983d5', 'CASSANDRA-306'),
#  ('849a438690aa97a361227781108cc90355dcbcd9', 'CASSANDRA-306'),
#  ('66c8f2b7f79fe794cc1e0594d9add260c209a9a2', 'CASSANDRA-306'),
#  ('81ffc4601952ff3a9fec8493cd27fe52544ea115', 'CASSANDRA-306'),
#  ('6c867f00309a61af12fa452020c45dc0f2748aa1', 'CASSANDRA-306'),
#  ('d06ed9ffc1e6a5dab6ecd47143db804dd0bf6cd5', 'CASSANDRA-297'),
#  ('0d24b1a802f67641b534cf2a407342f6129862ef', 'CASSANDRA-297'),
#  ('1de8e39ed5a00795ea16111931ca081024b4f325', 'CASSANDRA-297'),
#  ('304eae3b799759d334fcc50cbc3439608e1a2647', 'CASSANDRA-297'),
#  ('7fba3d299060f08bffbc9f58ee72df37ff28d8a5', 'CASSANDRA-297'),
#  ('afe2420b9561ddcb6bf77b264b633e278218731f', 'CASSANDRA-280'),
#  ('f7162293d2d61319be25aad49e76546ab335b9ff', 'CASSANDRA-280'),
#  ('7323f51e8e1bebc1abeb96141f350721033e4c96', 'CASSANDRA-280'),
#  ('d19a6af6674c883721cbc966757027edda26bcc3', 'CASSANDRA-280'),
#  ('9966419dbda995421f41ccc769d3b89d63940c82', 'CASSANDRA-280'),
#  ('13172bd993f86d44245e7140898c03db1a47073a', 'CASSANDRA-280'),
#  ('aeb0d5467d24b8b6c844de7566bfb5c58ddc5e27', 'CASSANDRA-814'),
#  ('0b60c8f37694d44482768ebc327989f7a42c8c08', 'CASSANDRA-814'),
#  ('23512cf3da5e8206d8797841f2238cdd86c13d96', 'CASSANDRA-814'),
#  ('efb5d036113898186bbc8a0eb0626c9c37fab588', 'CASSANDRA-814'),
#  ('e3902bcdad79dcef43562a075d6a130c6a77d63d', 'CASSANDRA-814'),
#  ('8959c1f1fc064bcf1f55febb3359c32ed748d1fc', 'CASSANDRA-812'),
#  ('2d80e9904b46474b3a7cc135690c27511a234713', 'CASSANDRA-812'),
#  ('4c3b42612037a74cb7095bdc8485ff42f747b2b4', 'CASSANDRA-812'),
#  ('f32475a839e01e4eea3989871d293d70e8a360d7', 'CASSANDRA-812'),
#  ('5c84ed9ae8227e550630768a47fef7b2d1f1f1d7', 'CASSANDRA-812'),
#  ('09d3507fb3c4794e310862ac2b27271798a45b37', 'CASSANDRA-811'),
#  ('d12cb030690a2673a88d043a265382bdbc7f0009', 'CASSANDRA-811'),
#  ('5ed5e84613ef0e9664a774493db7d2604e3596e0', 'CASSANDRA-811'),
#  ('72ca73fbc6bf5de0235f01d5f79b585ceed59949', 'CASSANDRA-811'),
#  ('865b67b21d326728936f0b80681129c73a2e374a', 'CASSANDRA-811'),
#  ('8bb9c72f582de6bcc39522ba9ade91fd5bc22f67', 'CASSANDRA-811'),
#  ('f43e6217e3d38703eb81f2bc50db8d962de55d94', 'CASSANDRA-805'),
#  ('3f83c10ef103a485d12489cdcf62c702f859339c', 'CASSANDRA-805'),
#  ('fa77676daa8e9726fd6ca96bb081cd288a21c200', 'CASSANDRA-805'),
#  ('545809616c92a91e4c39d1eedfa65800f25a2a93', 'CASSANDRA-805'),
#  ('c933bb326899b83dd136f8a31b090849c802084c', 'CASSANDRA-731'),
#  ('a4053682e84a18bbff414eb89fafbed92b6a7b14', 'CASSANDRA-731'),
#  ('ed806594e5169458d744a06c73ec224a1f37abce', 'CASSANDRA-731'),
#  ('7925f91dc842834c39504b5f9a68db9b5c9fd879', 'CASSANDRA-731'),
#  ('236c47e65ce95dcc7c8c75706715b5a2a88fd237', 'CASSANDRA-731'),
#  ('f25a765b6daf4d08694303f47bfe5f38185dd7aa', 'CASSANDRA-731'),
#  ('6c3bf55d02ef2983a03e59b2ec28337898ea6b1e', 'CASSANDRA-611'),
#  ('11af73aae9498cd8cea56e21a1f4fe48a6505bfe', 'CASSANDRA-611'),
#  ('7ff40061958006bd45ede949ceeb09e813d654e6', 'CASSANDRA-606'),
#  ('4d5c1325d5f92e1674bce232ecb94e1329a7002a', 'CASSANDRA-606'),
#  ('b9495d8e8e991fb82c6e5fe938116b40ae2d6128', 'CASSANDRA-605'),
#  ('ab35598e153c891a2401c63e900472bf880ea11d', 'CASSANDRA-604'),
#  ('38fc1ffbe302291b1990cbf2a5fee84afd6cf5c5', 'CASSANDRA-604'),
#  ('cf251697b9de6124594b81cd55b862f06b4e6e07', 'CASSANDRA-602'),
#  ('26be0652f3d705501ce4764e0901caf6a5a4c650', 'CASSANDRA-601'),
#  ('6facf088692293adc0d30e9a308be1d70236f28e', 'CASSANDRA-595'),
#  ('87ea405523c59349e2fb87c6dab5dc5a692b8b99', 'CASSANDRA-591'),
#  ('dfe86035f29122973bcbb6a384f44c672fe490e0', 'CASSANDRA-588'),
#  ('18084b7933c473c1800fbe8f824338d00bb20cfb', 'CASSANDRA-586'),
#  ('1331479f16c3e6aa475b0119af4e8e4b2006f232', 'CASSANDRA-586'),
#  ('fe4fce6b6587f956bca84e4fbae1c7b5a3464e7f', 'CASSANDRA-581'),
#  ('04af85b0648e627a1c00759a283e6a9bc67aa6e9', 'CASSANDRA-578'),
#  ('ff40e42ca36fc38151b525bbfd2c844b2cab2dae', 'CASSANDRA-576'),
#  ('fc4a261787cf3a59b09edf188b73e35f08ca5b2d', 'CASSANDRA-575'),
#  ('c3d275800284acca6300595db268ca0c92b9a581', 'CASSANDRA-572'),
#  ('53286d56f084270a457d8698785a189b8b410cc3', 'CASSANDRA-560'),
#  ('9fd0cd4a0a872a0c942ae1f50420e5372ef69471', 'CASSANDRA-557'),
#  ('55c153f2f6ba798fbe3acd0b92fe61a18d40c6b1', 'CASSANDRA-555'),
#  ('778d33d4aa83b1871d551245a5ba1693f4e1e68f', 'CASSANDRA-554'),
#  ('c9499e85813970a65796356189e9356083018dbc', 'CASSANDRA-552'),
#  ('2c06b0c9fd62f011969378304501770ef1fb24c0', 'CASSANDRA-552'),
#  ('25f1ed51247b966d9acf1209d6ad47f41dac03aa', 'CASSANDRA-548'),
#  ('ecbd71f6b4bb004d26e585ca8a7e642436a5c1a4', 'CASSANDRA-548'),
#  ('a23547d9aed3a9c29429cbf36be30055bd40c8ad', 'CASSANDRA-546'),
#  ('88c94a711086f32c2010efae1feb5a18f8ae0df8', 'CASSANDRA-546'),
#  ('f51da9a724bcf584543000f356c8ab13f448eaa8', 'CASSANDRA-546'),
#  ('31ca1b42388d8aa59f4fa26f3058011ed905613c', 'CASSANDRA-545'),
#  ('59f87afa7a61fc2d865468d23fc46b98c77c123d', 'CASSANDRA-543'),
#  ('6aa5b81d24881f11cf218468b7a4267fd054b1ad', 'CASSANDRA-538'),
#  ('855d997cee3a24a99964f5e1604c5e1672ce1485', 'CASSANDRA-537'),
#  ('b2978d2fc1b5c2ab0d845ebb99e503f64f9fe5e8', 'CASSANDRA-536'),
#  ('4deb77971a43cf5a55bd2e2835255ff044137fc5', 'CASSANDRA-536'),
#  ('000e0ff04ce0d80281e4a8616646e0d215d400b0', 'CASSANDRA-533'),
#  ('7d567af62cf07e40b8f9f6d600857bdd2f486008', 'CASSANDRA-529'),
#  ('4b92b79532fec22e7c0df9676394357354b1fe6f', 'CASSANDRA-529'),
#  ('4254bcfb961462190d7dc9c1e432dcca96861ad4', 'CASSANDRA-528'),
#  ('de9b7eb22587fe0bc501d6218ea49dec90860e44', 'CASSANDRA-523'),
#  ('7b553a8eb5b42395ac1683c1bc362671b5c1a7ec', 'CASSANDRA-521'),
#  ('8098feff101cc63182b19af04d678b7c0b8b836d', 'CASSANDRA-1221'),
#  ('c67a22ffe4fc2a86aa43b4d770889b8d3c84f988', 'CASSANDRA-1216'),
#  ('ef9c9f3f3ccb4c5bbf007680be3756ae43659b83', 'CASSANDRA-1209'),
#  ('8db18bf023cf58010db02921f0443b6f8b5b885e', 'CASSANDRA-1203'),
#  ('f73bab353c50d67252c13594ee836961902edc09', 'CASSANDRA-1199'),
#  ('493ecaa10af637b47af5735f081917b6bd1ad6a3', 'CASSANDRA-1198'),
#  ('96e530594a65b2b09abda9ad0716324a39222de6', 'CASSANDRA-1190'),
#  ('d718dddd6ea1eb4584c4b17151cfdcb11da9236e', 'CASSANDRA-1188'),
#  ('e5f87d1d91340db050a9a4efa954a82ee371aafa', 'CASSANDRA-1182'),
#  ('88f47b80c53a4d4587130ecc4e5fb6e94eca2659', 'CASSANDRA-1178'),
#  ('f100754ae8b1217d03719efc9c1441f6fc086fed', 'CASSANDRA-1175'),
#  ('0ed735570d80c42f4f279c54d652d9b1a2833e3d', 'CASSANDRA-1173'),
#  ('85180d62ca7515af68102f5b85f212e7a5ca3e1a', 'CASSANDRA-1172'),
#  ('d6f6285f670e30e5c519e246c1ec05dc9b3c3888', 'CASSANDRA-1170'),
#  ('436f3d0db54d7f5021c18612b18769ed758a0191', 'CASSANDRA-1169'),
#  ('92b166df95bbd5aff92607e1cf2748619c757410', 'CASSANDRA-1152'),
#  ('09c1e67598d7a0dc7da7bebee358fbc96d84680a', 'CASSANDRA-1152'),
#  ('eb208d3561eaf645f74f60b54c71ebe5bfc24c33', 'CASSANDRA-1152'),
#  ('d208e0359c75cfe033acda885720fcf83f06e620', 'CASSANDRA-1150'),
#  ('03be6d792679d8d4be560c9af4cba72e6b061f35', 'CASSANDRA-1150'),
#  ('c32a848008061dd3dc9e44b98f48320469988070', 'CASSANDRA-1150'),
#  ('bbee4c87c46c333260c876ea3f15935db9b1f343', 'CASSANDRA-1150'),
#  ('c9e6991b2d46b9c224a56f06355c88fb5d996997', 'CASSANDRA-1147'),
#  ('63703afefdad89d649559238f7d93ba73c62778b', 'CASSANDRA-1147'),
#  ('b1edd7cd58c329ddab4d0fcf8fd6aa106b74523a', 'CASSANDRA-1147'),
#  ('49d8b3f49a444261e03b60bf4c8f260808d00fab', 'CASSANDRA-1147'),
#  ('6f401a872584f7bceb12e3fcb1927287da687e7d', 'CASSANDRA-1147'),
#  ('f352f2b6372cc879c63ff535c684cbaea9e0f152', 'CASSANDRA-1147'),
#  ('24f5b64f2616daa3a3dabe34deb7fd6ebfc43429', 'CASSANDRA-1147'),
#  ('853ae8c84049be875921a40c9d5924724cc72792', 'CASSANDRA-1147'),
#  ('acd815898d1e5669e7d8ee2469808f6e8a14a7df', 'CASSANDRA-1147'),
#  ('6aa5925733429ae64505b68352a28a91b9b77d7d', 'CASSANDRA-1145'),
#  ('a6f8dd10cd8b283339c08b50ed6357b213b89dc4', 'CASSANDRA-1145'),
#  ('70b95d80985e9165528e0b22f32fec187098e0ff', 'CASSANDRA-1145'),
#  ('4ac89e6451b2ab0e62c04e61c60ba760f6c10223', 'CASSANDRA-1145'),
#  ('2ff1ad4788a1e29b99f81f75b2966b7951ba8250', 'CASSANDRA-1145'),
#  ('1751579be28f0c0460fb01fdd797b7f7e5cc431f', 'CASSANDRA-1139'),
#  ('d32fd5567a164d850e9490347b71624a1a17aadf', 'CASSANDRA-1139'),
#  ('1a37ebf553f39387971fe1f2df2c9da31a21a01d', 'CASSANDRA-1139'),
#  ('4e17922b61d6e90151c5e165ddbf0731232e566a', 'CASSANDRA-1139'),
#  ('5f7175d59da8b8d20e1081619eadad8b60867e86', 'CASSANDRA-1139'),
#  ('be574fc34ba9834929f1618ab63dd74446cd2683', 'CASSANDRA-1139'),
#  ('8faa2a2c6968221453a144954c219e9a0d90f0e2', 'CASSANDRA-1139'),
#  ('59b566bec3e0910287b18c9f6187cbeab63afd9a', 'CASSANDRA-1134'),
#  ('fb95112427a8c64344563b6e499a6fb7bbf538d1', 'CASSANDRA-1134'),
#  ('b3256f5bf22c99a8f5410634dd41ca1643a34c1c', 'CASSANDRA-1134'),
#  ('f5df4b219e063cb24b9cc0c22b6e614506b8d903', 'CASSANDRA-1134'),
#  ('f038059e89b089a19c36b3be58a443b0586fef5c', 'CASSANDRA-1134'),
#  ('2f5f0c2c12a2d9c91cad79655b80382a2bd4c132', 'CASSANDRA-1129'),
#  ('e08c7a6295eed716e9973fbd809dfca32d68a3e8', 'CASSANDRA-1129'),
#  ('9f58d76f3841864be11f5b9c4534027451328569', 'CASSANDRA-1129'),
#  ('3775c8f11dc998ba9c74769a14b9443272c750c6', 'CASSANDRA-1129'),
#  ('797b96958af07945b0a1799024c1ef664dfee2e2', 'CASSANDRA-1129'),
#  ('58a3b12508f97e44d3812f6c97e5a969dc6b5a1b', 'CASSANDRA-1129'),
#  ('eee211fdbb517c1b0e0a8635e0813bda7cf655e5', 'CASSANDRA-1129'),
#  ('58f5301e78d7f7adbbe4b3c6d0528b1bcb4c27bc', 'CASSANDRA-1129'),
#  ('602ffcbf3e4ead4732fdf46d506165f63d80a9a4', 'CASSANDRA-1129'),
#  ('e5df4413b23ee1eb9c750ccf5c73a542efd07696', 'CASSANDRA-1122'),
#  ('d25adb498abde240cc162cfe4a9630c01381c7f9', 'CASSANDRA-1122'),
#  ('377e114cb1459895423c292cb0bf7f921fd30e43', 'CASSANDRA-1122'),
#  ('c3321c9a2cdadc8d2f47bd9b8411ff983c72d71f', 'CASSANDRA-1111'),
#  ('7119cf8be1c32fa6ac015456965ae27a17cd828c', 'CASSANDRA-1111'),
#  ('924cd8f52c2437d0a0ce8c48196bb6aa8976fbb8', 'CASSANDRA-1111'),
#  ('0894fd97a2df87dd833272c5db16fb3238e11012', 'CASSANDRA-1111'),
#  ('4a555f47ee943ce9fd70862cc8127d707e3507a2', 'CASSANDRA-1111'),
#  ('f6a04ca81f2d0d8973fb7a99569c118122c500a2', 'CASSANDRA-1111'),
#  ('ac4d0161471bc5bd6971226a30074f3e8ef4879c', 'CASSANDRA-1107'),
#  ('89fbb1acf42c97f57ce7301674ab6f9647320c65', 'CASSANDRA-1107'),
#  ('ffc4c89c3df7ad0ae73ebefdcb7e15a2790c0a52', 'CASSANDRA-1107'),
#  ('09692d5a58d96089c699f59e9b7daacd066e902d', 'CASSANDRA-1107'),
#  ('53b49b1180dd2299b76709b4e7cf2ac184d2190e', 'CASSANDRA-1103'),
#  ('7db3285e7b745e591dc4c405ae9af6c1cddb0c79', 'CASSANDRA-1103'),
#  ('c26dc06a28b0e150384474001ac23026ae76e6d5', 'CASSANDRA-1103'),
#  ('7ea24711cc10dd4d846427f76c30c347cbdf3d26', 'CASSANDRA-1103'),
#  ('f809b6753cbbd27deab40679b99d956c8193fcf8', 'CASSANDRA-1103'),
#  ('c747f70c058aa94d6bcfe1f9132c410db6d2b65a', 'CASSANDRA-1103'),
#  ('519afca7922d3b44870d4276edf6796c95ffebe4', 'CASSANDRA-1102'),
#  ('6bd373f5d27754f80384caa31d1b2a4cfc43bc19', 'CASSANDRA-1102'),
#  ('4bb1a07b5be16b35d33ef5a4645a1209dffa9759', 'CASSANDRA-1102'),
#  ('8f878b7931b3ba250842e7b48ac569abf88dd3c1', 'CASSANDRA-1098'),
#  ('fd1f245353584833b8569666c115c6c64755c2c9', 'CASSANDRA-1098'),
#  ('a6864cccd4c0631a3ae88242739bc592755c349c', 'CASSANDRA-1098'),
#  ('1a4dccd3b9f9bfefbccbbe383982306d3aeea1d1', 'CASSANDRA-1098'),
#  ('bdde665032679bd197566cfeea34b52538da4f1a', 'CASSANDRA-1098'),
#  ('885836bc492a09bba2f11cba3cddb7ab15a00dc1', 'CASSANDRA-1098'),
#  ('910bbb9b5fced249696930c2e38240a9b0f51bb5', 'CASSANDRA-1098'),
#  ('20175bf77e2c6f72c25240ee445b583805a37630', 'CASSANDRA-1098'),
#  ('74bb6d8496d5a2a5b89a843ba764fe37b65ee331', 'CASSANDRA-1098'),
#  ('ce515a3d77c2042575827e8bdb1da639fc957491', 'CASSANDRA-1098'),
#  ('033d51a590ac383d4b0b05faeeb51b24f3980ca7', 'CASSANDRA-1097'),
#  ('05fa92475ccb2beb70a96ddee83c04b65a2cdbfb', 'CASSANDRA-1097'),
#  ('d70f6e0d597e888b3629c6c01d05685cf79a3d12', 'CASSANDRA-1097'),
#  ('f28dd90feb215db85ac2e510c5657a49edd46e12', 'CASSANDRA-1097'),
#  ('cdc0ce1fa33756f091785b58d4cc8f50fa9e7d0e', 'CASSANDRA-1097'),
#  ('0b591df6fa170720ef6c5c096db39abf09a7f3f0', 'CASSANDRA-1093'),
#  ('27ab63f00501a6afda94e760efab8af3e90c598b', 'CASSANDRA-1093'),
#  ('8def4fd7fb5fd73cb06e66381c3de3b99e397f07', 'CASSANDRA-1093'),
#  ('60675cc2759db0c5629604279e70c51e10dfefd6', 'CASSANDRA-1093'),
#  ('7275443eca804f5dde405f45811441dbc0c1f9fb', 'CASSANDRA-1093'),
#  ('9711f541b33ec2043de04cd4c47cafd122538b4a', 'CASSANDRA-1093'),
#  ('768bdffe5298b937bfafc2eb42fb93454cfca521', 'CASSANDRA-1093'),
#  ('c48906394e01460382f4070ecc34f6f9754fc567', 'CASSANDRA-1093'),
#  ('8fc39685fbb6c963cf0d86fd458069ab80bbcece', 'CASSANDRA-1093'),
#  ('51ce71881c87df754969809b5f6b2a466abc1e35', 'CASSANDRA-1093'),
#  ('5362293ed2b1075a243185691ecb0d4c7fdbc876', 'CASSANDRA-1085'),
#  ('91eea35343c1a6347f8ae98739ce2f6deff83ed9', 'CASSANDRA-1085'),
#  ('91d08e496ee439a2179e617f4db8804ab07c301a', 'CASSANDRA-1085'),
#  ('c6ee15ec486e71db528f00c6f649fd668f6bba13', 'CASSANDRA-1081'),
#  ('9ff28fc717e7926b5cf7c8acc85a35e0cfb43595', 'CASSANDRA-1081'),
#  ('647ec92db17e1b1a3677e7880849a29c0c30adde', 'CASSANDRA-1081'),
#  ('13d495aa7d5b7a7c121fcc9e105f79107c5c2a1c', 'CASSANDRA-1081'),
#  ('602605f45b42c4d2dfb117cf261129354760c1c3', 'CASSANDRA-1079'),
#  ('ce7502a11067ef903cba24ad588cf0a5b9da9257', 'CASSANDRA-1079'),
#  ('eac9d925621dc1757ac88ac7160dc0b2bd3e0015', 'CASSANDRA-1079'),
#  ('dd08314ed654aafa60b2a82fc4953aac171ba3ef', 'CASSANDRA-1079'),
#  ('88dc64d2086c9a91f00ee024b8ef13cb2c193ee6', 'CASSANDRA-1079'),
#  ('edaa958c3f75c61f69aa76ad6b6b3f175eb21861', 'CASSANDRA-1076'),
#  ('186eb9f7b8c05ad2abe9249aaef627334b3abfbf', 'CASSANDRA-1076'),
#  ('5a0a445bd8eb69ef5bc518a4cffbd34abb81f6b8', 'CASSANDRA-1076'),
#  ('439a980be2877153e927dff37c0084dbe9ab3910', 'CASSANDRA-1076'),
#  ('96588d4f322dfbb1f5ff9328afe4377babfb1d2c', 'CASSANDRA-1076'),
#  ('2993584fd8b537c192b49d5b3f637f38ed52174a', 'CASSANDRA-1076'),
#  ('3dc8066547de9c31be09cba912ddbb3262fd4870', 'CASSANDRA-1076'),
#  ('b0fd9e83b73a88f144f3a9bbe27e06c041e38d1f', 'CASSANDRA-1076'),
#  ('5ea3dc3f61010ccf8591bc52460a7ba419978eaa', 'CASSANDRA-1076'),
#  ('13e73255d8eb429050e714971b47aaf6d8cc36c0', 'CASSANDRA-1076'),
#  ('3c58e6848ba94b054b7e157f0c9b726d974208f3', 'CASSANDRA-1076'),
#  ('78bfb1ea24927b0daf2c2ab925c123640df3ad2a', 'CASSANDRA-1076'),
#  ('477eecb1cc5bcc5fa10e130c93a54864d1f56f86', 'CASSANDRA-1076'),
#  ('1c79c6823c6eac002d912afb979f6f9fa7fe61e6', 'CASSANDRA-1076'),
#  ('33fd2dc817f56116af0b4b7d2cd5365ce52948d9', 'CASSANDRA-1076'),
#  ('4aab2c79b9539e8d8cfe90e4dd700b8da2f9e8a0', 'CASSANDRA-1076'),
#  ('95522f85d5e14734f9af3096953974a4f48a884f', 'CASSANDRA-1076'),
#  ('935bcf1e8732a4138c15205896945c2f02ddb844', 'CASSANDRA-1076'),
#  ('b3842de5cf1fa1b81872effb4585fbc7e1873d59', 'CASSANDRA-1076'),
#  ('4b7069c06c7913e1f3f2d5622d8cbc04746b0bac', 'CASSANDRA-1076'),
#  ('8720e2e3322b4b6a04ecbf3f1a99746ca557b9bb', 'CASSANDRA-1073'),
#  ('0c4653110d80f411d2c50445d48478967bcaa095', 'CASSANDRA-1073'),
#  ('5ab15316e1cd83c129f3a66ba89e0fdcb60e4dfd', 'CASSANDRA-1073'),
#  ('10103d353c3d63505cb119cda0e38e692cdb1809', 'CASSANDRA-1073'),
#  ('0c0e9f69c21ae3a7c12a441ae033ab574a1c39b4', 'CASSANDRA-1067'),
#  ('138569b079b3d17b1020a24463adabecd903b79f', 'CASSANDRA-1067'),
#  ('63292292b8dbe3bb4f691f82823dcdc0172d2291', 'CASSANDRA-1067'),
#  ('29aa088ab69f75220162f1282c5f73c9e1993752', 'CASSANDRA-1067'),
#  ('44d81b5d09147fa2de505b4f03bcaa2e9017a9b2', 'CASSANDRA-1067'),
#  ('be9db0980b9525d67a2853ffb3d2bebaf87ad8f5', 'CASSANDRA-1067'),
#  ('e137c7c34cc10d4f8c9124c6f9af17a44061ab1f', 'CASSANDRA-1067'),
#  ('9d9c6d2750babc746f33f4b54f8f60a11d2ede86', 'CASSANDRA-1067'),
#  ('55f094a6d2c288b74e6ea86edaa7c45cd494c208', 'CASSANDRA-1067'),
#  ('e9b9baa54fed4ee1539d1e02bd435f53a069dad2', 'CASSANDRA-1062'),
#  ('43b750341e2fd33559353d53d059a0cbc3911cb1', 'CASSANDRA-1062'),
#  ('fbb20b9162b73c4de8a82cf4ffdde3304e904603', 'CASSANDRA-1062'),
#  ('7741eacc546f80fe4324c7821fcf2c029f64b1f9', 'CASSANDRA-1062'),
#  ('35f496d944af66d7e9d4be65eb704d387fc8da0d', 'CASSANDRA-1056'),
#  ('f4ab8cce1e4f517406c1343d369326916586db67', 'CASSANDRA-1056'),
#  ('e6946e7ddb76bd72109995664289e988b0e9818c', 'CASSANDRA-1056'),
#  ('d93e43ed9b3abad438c4ec9db6ae94d768f52896', 'CASSANDRA-1056'),
#  ('5f23e6d766a18782db82d955bf380239990d2c84', 'CASSANDRA-1056'),
#  ('eadb171d5dfa9de3ecc6dce47515d48771fa98f9', 'CASSANDRA-1056'),
#  ('1db5b3d6cf044e288b14b8e73dee01beca44d3e1', 'CASSANDRA-1054'),
#  ('5bd8207cd78d247b8110a49567c4787025f6cc4f', 'CASSANDRA-1054'),
#  ('b69297ebb28dc8b4e110c2d9785a04f91acb5558', 'CASSANDRA-1054'),
#  ('b67d04b6fe311d8c923d125c722e7a094a921f0c', 'CASSANDRA-1054'),
#  ('fb76baa60898db82831df44796bd224d30e3236d', 'CASSANDRA-1054'),
#  ('dcb5c280d2cd0ff4b7df8ce203cc3ccaca4429cc', 'CASSANDRA-1050'),
#  ('1185593907ba6597c29da1dfb5e6edb121b358c5', 'CASSANDRA-1050'),
#  ('c52f50f046fd1a8e1c7f17d9a1952e2bd92aeb4c', 'CASSANDRA-1050'),
#  ('038271cc6f0dda7ca45dd3a4c52fcfd23daa2107', 'CASSANDRA-1050'),
#  ('3b1d7c36d18ce4b314b007ef439f860dd2ef7460', 'CASSANDRA-1050'),
#  ('14fd0ad4e3102ec626af22e5007663526fbebbbe', 'CASSANDRA-1050'),
#  ('cf1a65498b6c01405e47511df76402a08ab7127d', 'CASSANDRA-1048'),
#  ('d42087a63309178b96909c012dd0073fe0b6ea11', 'CASSANDRA-1048'),
#  ('a1285ac92ded45ab6e9f6c7c98917daf14a4a320', 'CASSANDRA-1048'),
#  ('17d379ca1be7b7b4d490cda39dcc1b30f5cb3bd3', 'CASSANDRA-1048'),
#  ('a1210aa28d111fcd614691ddf83d3af340262203', 'CASSANDRA-1048'),
#  ('53b0661cbbe705901d7a891c9c6ba34a42f07427', 'CASSANDRA-1048'),
#  ('4b018b5bf4117d2377a67a495a40a7d7e49b30f5', 'CASSANDRA-1048'),
#  ('3259d6de37ad8ad231d44ccd4ca9c378b987f835', 'CASSANDRA-1048'),
#  ('3d7c824c1bc81998492a23b69947ecd6fae54f53', 'CASSANDRA-1048'),
#  ('2fdf1d27620fe2bce2a3c5989beab40b05fda1e6', 'CASSANDRA-1048'),
#  ('e6950518d15da7c0b5a1bb6304f911c056426df5', 'CASSANDRA-1048'),
#  ('4ea7bb25b4079e951202762aeaabe1d23be5303c', 'CASSANDRA-1048'),
#  ('0692c1397274b8fb106f4b7af15d0c776139a2fb', 'CASSANDRA-1044'),
#  ('3291647a96efe6265ed905b0fe2144e5370bb5c6', 'CASSANDRA-1040'),
#  ('bc4dd9335f947eceb90f00581b01bd6533ff523e', 'CASSANDRA-1040'),
#  ('dc342de3711a5000be536cae6a661bbd44733398', 'CASSANDRA-1040'),
#  ('dc76b2764a6b70cfd3d41862e413a0f8e6f095f4', 'CASSANDRA-1038'),
# ...
#  ('6a9a336ad4a4621aeb7bf73a4e6cd15aaf74323d', 'CASSANDRA-1025'),
#  ('67949f63f19f6397f4aaac7bf0f199b136d4addb', 'CASSANDRA-1022'),
#  ('203e2c2d9071fe003794d20cb92915d2e56b46c9', 'CASSANDRA-1021'),
#  ('57684e9aab65c7ecff60c108d8d3c183073088b1', 'CASSANDRA-1019'),
#  ('69f4fec007989f2ce47a59abf84a98bd02ed8fac', 'CASSANDRA-1011'),
#  ('7e40e39a4e42d13887f4bb6771238ccd8f11f05c', 'CASSANDRA-1002'),
#  ('2dd17718d250e9c1c53cbd7ae8e6ed8105887dae', 'CASSANDRA-969'),
#  ('3d9305b505471db21bd73d79a95d7d4a4981433b', 'CASSANDRA-966'),
#  ('1f75bfa1a854fdf9a6a635cba6ff6abd9d9dd814', 'CASSANDRA-966'),
#  ('21b5cdb899a7a8ea24b90810e2d32716acc3d7c5', 'CASSANDRA-965'),
#  ('eb42d3add3c9b3809a566c1de6facc07f508a65b', 'CASSANDRA-961'),
#  ('5fe482029e771a3ae5cad4f51a475181460ffe4d', 'CASSANDRA-960'),
#  ('b3c5e42fe83ceccca9d4a7e2f18207009ab199a0', 'CASSANDRA-960'),
#  ('d2c98b024d85bf72a6ce3e03d0b8d2994199c254', 'CASSANDRA-954'),
#  ('022208bf0f3099b91143a76e8b57d5fa63671269', 'CASSANDRA-952'),
#  ('c8f2414688e11b457be8305017fe34db0e85ffe5', 'CASSANDRA-948'),
#  ('a1c1abfba6989872ac354ff9528c0f088cff4887', 'CASSANDRA-945'),
#  ('7f5636cfa69149cea784fc064c5285ea936c4389', 'CASSANDRA-945'),
#  ('5f8991c73a6f43fbe9c7e0d8906e751c21d54412', 'CASSANDRA-943'),
#  ('0dc0029e820783f168297bdafd6169d03aa6ea20', 'CASSANDRA-942'),
#  ('d719e5787cfbae2201384cb94290f673879fc56f', 'CASSANDRA-938'),
#  ('972ec741406b9ec2746083e5de65e6c10f7470ef', 'CASSANDRA-938'),
#  ('93ef5fa8492bfdb44f6a91edb34818fbfb35c9e5', 'CASSANDRA-935'),
#  ('d383294daf148e7246786313706917fadc6ad50a', 'CASSANDRA-933'),
#  ('28414b198c579cdda7f1af47eda33108315afd81', 'CASSANDRA-922'),
#  ('b9b1ac3ba0d0ede6d5ac2fa047203792994e7a43', 'CASSANDRA-921'),
#  ('b3c8987036fd0a95e35a0ab1b174299bed566bfb', 'CASSANDRA-915'),
#  ('d24d7ce6c47637512864892c222f396dd6eaa6e7', 'CASSANDRA-914'),
#  ('520c565a36364c25e821f96f9c88f84b9b559445', 'CASSANDRA-914'),
#  ('832a45d89c42869769e159a1154759edeaf5b5ef', 'CASSANDRA-914'),
#  ('741c616ce95df93fac5c5cf4aebcf8bc3cc9a0f5', 'CASSANDRA-909'),
#  ('7105ae1dfd609230be8d9f09f0f4f0d1af0986a8', 'CASSANDRA-907'),
#  ('cbbd7c8ca8c8b89d899acc364ce8cab3251d2100', 'CASSANDRA-907'),
#  ('603f91874bca3d83cd8539691815de965a851fd1', 'CASSANDRA-907'),
#  ('d9d4176fdf352633c8f6bab9f5df987dea26b312', 'CASSANDRA-906'),
#  ('21ee75efc14bce1e55d08d96489fe0c7ea418fe5', 'CASSANDRA-906'),
#  ('4be0b109f02a68ce099a530a424ec3dc82d01a9c', 'CASSANDRA-902'),
#  ('27a5111811706c4ae6b4ccaf114b51d7cb6cbf7c', 'CASSANDRA-892'),
#  ('260b8770605106a4f6ff7e1af548d6ba40e54260', 'CASSANDRA-889'),
#  ('dbcbb0cb17d1c2969eb3fc95d4c488dd63cc07f0', 'CASSANDRA-885'),
#  ('ec9f6c2c970e47242cfdee6c64d7daf4fab30460', 'CASSANDRA-884'),
#  ('23706164f6e1495f2e2a21a454fd07ef0c7164a5', 'CASSANDRA-882'),
#  ('15a0f2b20771bfe21c7539c709cdb30032e652ab', 'CASSANDRA-877'),
#  ('7dcdcb726510ecb03b9f7e4cf27ae86018feeedc', 'CASSANDRA-867'),
#  ('bec58a0ab58824ba68d87a8c799857de4a14da77', 'CASSANDRA-866'),
#  ('b9dc6a60049118c2949ec4dc122ddc779a4973c6', 'CASSANDRA-865'),
#  ('453a67130bed7990fe018561f292ece899a5e3a0', 'CASSANDRA-864'),
#  ('1e20bf521da3fd3fd5837ea649646f38e14a3440', 'CASSANDRA-857'),
#  ('c8b6763b1d0377a9d42d0625792762f460185397', 'CASSANDRA-850'),
#  ('0021d35ee77cef59cc7ca9b37a1389791ded26e1', 'CASSANDRA-838'),
#  ('76fa3204383cb2cb306ea381a163471a392f578e', 'CASSANDRA-837'),
#  ('2e7ecdb6819d5e6f087097680ef4f60de41c8067', 'CASSANDRA-836'),
#  ('1e5f900646ab3e30de807e2f512cc6eec3ad4ae0', 'CASSANDRA-1645'),
#  ('dec9eec41f7a1c060db8a6bc946aa012c81b73f0', 'CASSANDRA-1643'),
#  ('726b7da8ad438c857218001542f164a3255479a8', 'CASSANDRA-1642'),
#  ('51a07442885360168fdad33b6da792911e07dd83', 'CASSANDRA-1641'),
#  ('9026700d7162acb4726585c5cf7c14123998d4d8', 'CASSANDRA-1641'),
#  ('48a072dac26e89991bed9e0a0226d3880389db99', 'CASSANDRA-1640'),
#  ('28ab378639e1717c3dccc5b91d84525108e68749', 'CASSANDRA-1640'),
#  ('aaef16ed122fa3cac60f9e7ac7448ce9f062c574', 'CASSANDRA-1635'),
#  ('98eaa99a6c0ed581108174dc32d426c5294f8e1c', 'CASSANDRA-1635'),
#  ('0fb4df971685d7616131063205b93007330a4ad6', 'CASSANDRA-1635'),
#  ('705cd1e8bbfe06246ca31894395eb101eb95d4a2', 'CASSANDRA-1633'),
#  ('86f6184d0d09f3f3a2c6d080c88e31810f373020', 'CASSANDRA-1631'),
#  ('ee1bb5aa95b1975981b31c13a08df069d520894f', 'CASSANDRA-1629'),
#  ('f5203cfef2790080bde0d83ec768e6884b276f86', 'CASSANDRA-1628'),
#  ('59b46bfaa953b879821424600c5545982519e2ec', 'CASSANDRA-1617'),
#  ('351c0244b5c7057b64c45575bae20e6fe808034d', 'CASSANDRA-1617'),
#  ('d9bd402bf51567bd9711bcbe1d74c80b7aec2595', 'CASSANDRA-1617'),
#  ('882adf0ae638c69928e14ed7e34de7364ed65ba1', 'CASSANDRA-1617'),
#  ('979ce41ef44a0444188f73ab0ab4ce8253d1c3fe', 'CASSANDRA-1613'),
#  ('92da3e2d60a37999110648528fc7cb7659dd66e6', 'CASSANDRA-1613'),
#  ('323ee4606cf4bd20cc98d2a2e7986386e9a83822', 'CASSANDRA-1613'),
#  ('8e180e8764d2dffd6c71ca399b51c24dcee268d6', 'CASSANDRA-1609'),
#  ('feb4f034fa8f8a990ae7ec596398c8a993731bbb', 'CASSANDRA-1594'),
#  ('a0498517f2feb70db1ad0cad5417577b11cd74cc', 'CASSANDRA-1591'),
#  ('22fc25b9a223205f89293c7143aeb15de3ce6cfb', 'CASSANDRA-1575'),
#  ('7a0ebb9cb565cc99e80d9a688a385b0cdb0f6294', 'CASSANDRA-1574'),
#  ('2c9fb38e14af1f4dc876ab446ead0390ecdd0182', 'CASSANDRA-1573'),
#  ('b934e1eca8c62b2929f3c80809306b74a57e79d2', 'CASSANDRA-1568'),
#  ('5947c5907258c81fce0ff8e8333fa9852ed31eaf', 'CASSANDRA-1566'),
#  ('0087c38a268d314172f06bcd522210ed8f226409', 'CASSANDRA-1566'),
#  ('d951f52538fc6423f0ac221ccb72473954465ca3', 'CASSANDRA-1563'),
#  ('d88fffdfffaa41e0f133b0be5518b67d6ee0d067', 'CASSANDRA-1563'),
#  ('20f83e459a05a938b523dbe643b00914109dfe8a', 'CASSANDRA-1563'),
#  ('3edbee223fed6aebe33ed8c5e168b4c79efead7e', 'CASSANDRA-1563'),
#  ('3e44d450a344ebad4373f2454d6675aa13f438b0', 'CASSANDRA-1563'),
#  ('46c014d9ec2374c28d9f39f37b678a631868c67b', 'CASSANDRA-1562'),
#  ('4618b41ea9374e09ee61e569da9ca4a4fedf81ed', 'CASSANDRA-1562'),
#  ('f652c69bf641c4d82d259c7ce81c2da1ea6c3f7c', 'CASSANDRA-1561'),
#  ('7d44bbd308beaa70bba7ea2e46c58441f8599b27', 'CASSANDRA-1557'),
#  ('c75b0c1d2b91d6101d6527b8c24fee2d0234b4ab', 'CASSANDRA-1554'),
#  ('3947dba35b605ad365e62d4c875ff76685bf69c9', 'CASSANDRA-1550'),
#  ('0c1d0dba6cff82e9f3c818915ee8c09f441c7491', 'CASSANDRA-1550'),
#  ('1f073123f61dd7245d1412adbccd4be2337705cf', 'CASSANDRA-1548'),
#  ('96d0a86fd983d840dee7c88b998f6ae80c847b89', 'CASSANDRA-1547'),
#  ('f659c6759dd2ec99472dfb194f82dedad3b5ae45', 'CASSANDRA-1547'),
#  ('0be3189b045bc41211a4dc1d411b8494c9da08c9', 'CASSANDRA-1545'),
#  ('b674d83e71166ab8d5b4438e21379560b40d8c8a', 'CASSANDRA-1543'),
#  ('ed2a60707a70e21f1a2a61416f6ce3c3f1e0865e', 'CASSANDRA-1542'),
#  ('12074044273f40e5f0a448792e3678a9f99bdb07', 'CASSANDRA-1541'),
#  ('079276622158fdfabe0cd8f727e55e0f963a388a', 'CASSANDRA-1540'),
#  ('8097545140716f0cbde4c9112a0de2d0b75698d3', 'CASSANDRA-1539'),
#  ('dd0da7cbbe6a93869fc68a1165aca2fcc3b9c80d', 'CASSANDRA-1538'),
#  ('c5f4f3b2be60652b380806c6928d8ec480d06941', 'CASSANDRA-1534'),
#  ('5e8b0d68cbc4763db5aa0a820a630f018f394f06', 'CASSANDRA-1529'),
#  ('67ed53c48a45956047c2d8be7c9a417ca88070c1', 'CASSANDRA-1528'),
#  ('f4a68eb778dddc118d6e366c72065275b2421194', 'CASSANDRA-1520'),
#  ('8aeb2fec07f8dab42b57c71a6514fe77d919f137', 'CASSANDRA-1513'),
#  ('03f24a9a32c24f2f4e1046ecd074400a65263bb2', 'CASSANDRA-1510'),
#  ('e91b3a6c398e51449221cc87a5a29bc1f495343d', 'CASSANDRA-1496'),
#  ('e860d2fdf53630f97f1fe067e8352843b165b97d', 'CASSANDRA-1495'),
#  ('d790ed1bc871a9bd3a8c8640629532c0bed77656', 'CASSANDRA-1493'),
#  ('5cdfaab72c6c8a2a9fab0d1a97fd1cdeafd6c2df', 'CASSANDRA-1487'),
#  ('5310620826fadd5f68975feb77e01d87b386b19a', 'CASSANDRA-1482'),
#  ('368aa0e965cfc1dac1da5736ba6329cf55f2a867', 'CASSANDRA-1480'),
#  ('b4ea3a73cafca1995c36248cd9a21a73b36bb34d', 'CASSANDRA-1477'),
#  ('d5311404a00ed458614b186925386dee2e07656f', 'CASSANDRA-1466'),
#  ('8b8a928e04bd091a6d774a9d5b9937d2002d7882', 'CASSANDRA-1462'),
#  ('055cabc36c56faeb27158db9f0bd51275787cb7a', 'CASSANDRA-1462'),
#  ('358769548a9fa451bce605aa518876da53a3dd10', 'CASSANDRA-1462'),
#  ('160cb28d97b3d14094e60f53cb760f3f145f72e3', 'CASSANDRA-1458'),
#  ('5e4d3055e9fafd052638099d77b102d81ad67317', 'CASSANDRA-1456'),
#  ('91c4cba8a58f229f3d51c33ce9a885d55758dedc', 'CASSANDRA-1455'),
#  ('6c76db57572ff8bf3656a5037217363dce6d467c', 'CASSANDRA-1450'),
#  ('e5f7b37e001a76ca0e53b07a8ff8f37e20c69ca9', 'CASSANDRA-1448'),
#  ('45dbeb7d30c2ab9b8e759dbe7ddf5bd9291a1ddc', 'CASSANDRA-1448'),
#  ('72199e23ec9d604449bef87733a32e1da9924437', 'CASSANDRA-1447'),
#  ('7954d69001dfb4205c45dde88d2f7b3e9457f31d', 'CASSANDRA-1446'),
#  ('c56760338ebb9f5a283b0e32a9d98ea81e273627', 'CASSANDRA-1444'),
#  ('852dd623eb5f3fcc69bd92554eb0baba0db443d5', 'CASSANDRA-1439'),
#  ('dc23a33efda97e95233c071dc5317cd6d0d27487', 'CASSANDRA-1438'),
#  ('3104648f9e75a288d11733add0ca20c192ca8a95', 'CASSANDRA-1435'),
#  ('5056f05a3235cddf96fb8daf197f932ee19bac12', 'CASSANDRA-1434'),
#  ('a40d00ba39463bb4495647b5a96ad812ef148b8c', 'CASSANDRA-1432'),
#  ('dbd8ced107fad720c416d7e4919cb33884378a02', 'CASSANDRA-1430'),
#  ('6173fa9e3443909474e14f5695e705df5b10dbcc', 'CASSANDRA-1430'),
#  ('be313935e54be450d9aaabda7965a2f266e922c9', 'CASSANDRA-1429'),
#  ('5927193d397ddbc7bf94beda213aae8f804bf58b', 'CASSANDRA-1428'),
#  ('7316f1813954414e1b858f7867c5a9b2724d67e7', 'CASSANDRA-1412'),
#  ('64b4e4f23dbd5020087200f478c7a69fa51db989', 'CASSANDRA-1408'),
#  ('59217ad0962b14f68f6f9c69e0bd4490a1d4756e', 'CASSANDRA-1407'),
#  ('03d3669bc656bfe09367ad51e99326b811149046', 'CASSANDRA-1406'),
#  ('fd188bfd384bee0ef056b5f9b0a0b816c15e52d6', 'CASSANDRA-1402'),
#  ('cc33799cb01581249ee0d07ef6626be00b968723', 'CASSANDRA-1399'),
#  ('3a6ae395ea6263ad69f8f218f43beab5a2b7579e', 'CASSANDRA-1398'),
#  ('cea1ada8c9fc6ff714adf5dc012b769b00c6795c', 'CASSANDRA-1394'),
#  ('6a958a90a8e95028fca55bd8f2e2ddcee7e1ce6a', 'CASSANDRA-1385'),
#  ('effb653450a11abd5e0fdc221f9b2c7a046e829a', 'CASSANDRA-1385'),
#  ('46e61bfeb31ce377676345aa878b4c6218c9e7bb', 'CASSANDRA-1384'),
#  ('a3324721ec66f62c32c4d3a9c209a9a0001c466b', 'CASSANDRA-1382'),
#  ('b42139c41abb17ffffd99b960adb73d3f9599fd9', 'CASSANDRA-1377'),
#  ('ec6096af72a84db37ce7568da05f9f94d92672af', 'CASSANDRA-1373'),
#  ('31358f11583ed799f71b5f47e147f518431f62a2', 'CASSANDRA-1366'),
#  ('f1cfc316e9a6ca4ec1f0fb64198c4f6ad89ac1b9', 'CASSANDRA-1365'),
#  ('ceabffaa22ece914c989a40a2e4e852cf26d91fe', 'CASSANDRA-1362'),
#  ('345a263db47796a3d145f877af14ee42666d3137', 'CASSANDRA-1362'),
#  ('476cecf9a717bb39eee80db1bb12856791f7a550', 'CASSANDRA-1359'),
#  ('04bd02682b38e6197628b8374b140be5d3b34e90', 'CASSANDRA-1357'),
#  ('fd53a7efb4fa950967c0ca4d60d741f51315a9ef', 'CASSANDRA-1356'),
#  ('6e088d48f363d0cdac998a14bb17f1b04cf5ca0d', 'CASSANDRA-1352'),
#  ('8289d6840388a1f868c14a2740e7f1bbefa0e675', 'CASSANDRA-1351'),
#  ('3942b06f05b796790a6a5a21ae68dd03c00da803', 'CASSANDRA-1350'),
#  ('f6937766a283389a28ddddb5e6320cac9b605a8b', 'CASSANDRA-1349'),
#  ('609bc4e123f08b8f65dbb45da3243719b7ccfdde', 'CASSANDRA-1344'),
#  ('430ff174ffed325bf9dca5c7813f378ade61a7da', 'CASSANDRA-1343'),
#  ('32182f09e115236d391f3d2f86a21ac2d408313e', 'CASSANDRA-1340'),
#  ('2cdda7688166d9ec84063ec907510597359c3090', 'CASSANDRA-1333'),
#  ('1596ae9057956706a9c9630072567ab615fe844b', 'CASSANDRA-1332'),
#  ('015c94c60313cbad00336f8ed14f922cb315f9eb', 'CASSANDRA-1330'),
#  ('bfac864064d19562ed9b50a94af8133fde075ac3', 'CASSANDRA-1318'),
#  ('e6c727b26d1db1eb9f3eace1ebd12860db25af86', 'CASSANDRA-1317'),
#  ('ab04470b27eba55c270280a5efc1d19a7edcd558', 'CASSANDRA-1315'),
#  ('cc4588af675e52c71ab7b0dcf697f25983eef906', 'CASSANDRA-1313'),
#  ('5d7e2fba24f99939e44dd082864c1dad55b3726f', 'CASSANDRA-1310'),
#  ('f44dc94ff5475b4ceb7c1c5a8a7377ee9102b7f0', 'CASSANDRA-1306'),
#  ('ffdfe1b102c164cb46885befb845057aa07102a4', 'CASSANDRA-1304'),
#  ('fcf01805be385964e4a2eaaba95f27262c126b03', 'CASSANDRA-1300'),
#  ('6139767e9095fecabf38cade374a3817f9858be8', 'CASSANDRA-1298'),
#  ('def08551773992fe6cdf0eeffe79eda9d917e235', 'CASSANDRA-1297'),
#  ('a9f031b1a579956eba1f04c15cd98777a7eee86f', 'CASSANDRA-1294'),
#  ('fb05f27d5196bde59cf15d1276cd6a7de82968e8', 'CASSANDRA-1293'),
#  ('1e36fb1e44bff96005dd75a25648ff25eea6a95f', 'CASSANDRA-1279'),
#  ('4624cb45655aaf231c49258d8796828aeabf560a', 'CASSANDRA-1262'),
#  ('466ff41a7d9449330dfd869f309c25988671090d', 'CASSANDRA-1236'),
#  ('c47d1781faea056a15b0d02d571c59b0e500947c', 'CASSANDRA-1235'),
#  ('6ec59e4f27d3ebb5a8962f9579695dde36d32cad', 'CASSANDRA-1230'),
#  ('1970f447f75a12ae3472b59849b65a46fcd9383a', 'CASSANDRA-2199'),
#  ('3ff82cb70fc02b63ea5eb8b6355e5f3aeddebec2', 'CASSANDRA-2196'),
#  ('09b87eb7a05a9757462afd052ac1ff029019d770', 'CASSANDRA-2196'),
#  ('7f9f79622aad20cb65349c9765fb43b0e0fa72b6', 'CASSANDRA-2195'),
#  ('37326e75f1541f6f7b6ab1a60338666df30ab0f5', 'CASSANDRA-2193'),
#  ('aeaab2445e3fcc022ee3d1c92eda8a56dd509b5a', 'CASSANDRA-2192'),
#  ('c953ee622b90d4eacc916461a2ae31d3f052b331', 'CASSANDRA-2192'),
#  ('9b9c4d32973ea4e586031775b3322180169135cd', 'CASSANDRA-2190'),
#  ('6eb154ba5616e0df3ce4f11c88dbb1c92d317465', 'CASSANDRA-2188'),
#  ('58e29caa2882defad24e6617667b39ef52da97d6', 'CASSANDRA-2187'),
#  ('850d1a4c907648d06c7ca93dab8d12fff0e17566', 'CASSANDRA-2185'),
#  ('8e701e01cdb656b65f8efa9c8264baf9f4a373f2', 'CASSANDRA-2184'),
#  ('a27f94e24ecefe7a0bc9786ba90cb993359b5fdf', 'CASSANDRA-2182'),
#  ('6ffe50521ad36a0ae5f57460881d5a9651a20ff8', 'CASSANDRA-2174'),
#  ('e37a12a7c1bb6e3ab7c15a906c778cc15702c64e', 'CASSANDRA-2172'),
#  ('d20f76251e63b0f763df130152f46942a653a5e7', 'CASSANDRA-2169'),
#  ('e51401b2b755b74384a17276e3a05913e5df05ea', 'CASSANDRA-2169'),
#  ('2f160464807686494e224417ccce8bb86a2f4e20', 'CASSANDRA-2168'),
#  ('65dcec661a1cade3ccd5adb1fa0b47b5df7b972d', 'CASSANDRA-2165'),
#  ('ab72dc9270bc14235ea81f7fc73da1b780f657e5', 'CASSANDRA-2165'),
#  ('6ef8513e235d324d53475a73756f70f32591abd3', 'CASSANDRA-2164'),
#  ('a6de715c07c380e6b967fb690a3c88a614d56c85', 'CASSANDRA-2163'),
#  ('365f11ce06c5b196f08851a9d89c122c24941743', 'CASSANDRA-2162'),
#  ('9c4c63ccae2dee3cdead7d2e83928e26d8a84a48', 'CASSANDRA-2157'),
#  ('c0af7f604189f9e2a21fed397ad32c43a8aff89f', 'CASSANDRA-2155'),
#  ('0b0d7eadfddeb16f22573f4ff1c31f4a1a0f006b', 'CASSANDRA-2153'),
#  ('5f5e00bc9a83bfd701723cbc7bf2307ea53da342', 'CASSANDRA-2146'),
#  ('893d1da990b4f31462ad241dc0c4b6a91cf3dbee', 'CASSANDRA-2140'),
#  ('9688a79d0c315395772d15d92e051d00e18b966b', 'CASSANDRA-2140'),
#  ('cd36f9757150db6a369d70f633971dadd571509a', 'CASSANDRA-2136'),
#  ('9417eb629963e0ed4e861e3fa3dea106841662af', 'CASSANDRA-2136'),
#  ('2d72056c14f9b97e67dd94e48691f3ec1a88d9d6', 'CASSANDRA-2132'),
#  ('d16c4468e86fbdb82ed981ef6c6ced6f275e4f21', 'CASSANDRA-2132'),
#  ('46722cc69e47e9b4bdcc5c28f426cf7f0a6a3a7d', 'CASSANDRA-2132'),
#  ('c9270f4e3ae5f94d46070f1c7e585c90bc68df7c', 'CASSANDRA-2129'),
#  ('fbb5ec0374e1a5f1b24680f1604b6e9201fb535f', 'CASSANDRA-2129'),
#  ('086c06ad7fb211de6be877c3c1ea2ee4f86c6d7e', 'CASSANDRA-2129'),
#  ('d74103735126658d64cb92a16f4bb40f63d5e2e8', 'CASSANDRA-2126'),
#  ('b527d9ffe1807f6ae1b1df15d64d1715bb33f4f1', 'CASSANDRA-2121'),
#  ('270850d793aa1a8ed408f682479117f3f8ff3f6b', 'CASSANDRA-2113'),
#  ('72364659f16f415dec104112ee5fa286674d278f', 'CASSANDRA-2113'),
#  ('7b1dd3d8f0191c7d53211a6312e591cd29128184', 'CASSANDRA-2112'),
#  ('3e1745ae5105ea7e7c33003ba42a562adb9a3cd8', 'CASSANDRA-2112'),
#  ('35aad40b05442b4c827cf8d373c65954d4b36748', 'CASSANDRA-2111'),
#  ('651bf357550c15eddedd762758667443166f3e54', 'CASSANDRA-2110'),
#  ('565f675b16747e7bfa827cb220cfce28f33c5b81', 'CASSANDRA-2102'),
#  ('3d55a2b033ee7c7333230af5ef7c83b44bd8c8f7', 'CASSANDRA-2100'),
#  ('22b8a9725b384c0fbee9356ef15e0728bbfd2a58', 'CASSANDRA-2095'),
#  ('f5f3065843da6d5d1ba173f433873c10f9a27f80', 'CASSANDRA-2088'),
#  ('c9cf050982f83cacfe973fc588fa385bcf544690', 'CASSANDRA-2081'),
#  ('2046956b6cfd809702bf33cb85a9cae091ce1d72', 'CASSANDRA-2073'),
#  ('359391fa835bb4eeba662f8155159c18e919b40e', 'CASSANDRA-2072'),
#  ('90e3ec44030b31f853dfd02d6cd3a4a74d990b94', 'CASSANDRA-2067'),
#  ('dfdf89cbc93917052aac5b9e1ed7581a1d026fa3', 'CASSANDRA-2066'),
#  ('739848602dc01b4f4d1893bf3aa38f5ddcf13267', 'CASSANDRA-2061'),
#  ('83119656a2f54db064ec1479eddb826d8fcaf7de', 'CASSANDRA-2061'),
#  ('cafeeebd17b208e12313bea9da0972e6f4c5cdf8', 'CASSANDRA-2059'),
#  ('aacbb1ca9c0e7a1992dfc92c096dd885ab149154', 'CASSANDRA-2059'),
#  ('185eca5d1fa7e384bb888c144d06abbced0fd577', 'CASSANDRA-2054'),
#  ...]

# %%
# Create a Pandas DataFrame for further analysis
commit_df = pd.DataFrame(modified_files, columns=['CommitHash', 'ModifiedFile'])
issue_df = pd.DataFrame(commit_issues, columns=['CommitHash', 'IssueID'])

# %%
commit_df
# Out:
#                                      CommitHash            ModifiedFile
# 0      1f91e99223b0d1b7ed8390400d4a06ac08e4aa85            JSAP-2.1.jar
# 1      1f91e99223b0d1b7ed8390400d4a06ac08e4aa85          activation.jar
# 2      1f91e99223b0d1b7ed8390400d4a06ac08e4aa85         antlr-2.7.6.jar
# 3      1f91e99223b0d1b7ed8390400d4a06ac08e4aa85         antlr-2.7.7.jar
# 4      1f91e99223b0d1b7ed8390400d4a06ac08e4aa85         antlr-3.0.1.jar
# ...                                         ...                     ...
# 98820  2b23fc58aa86a1cd0c98f97ddcf43305869d041e    jvm17-server.options
# 98821  2b23fc58aa86a1cd0c98f97ddcf43305869d041e        GCInspector.java
# 98822  15f355a0062148e1ca511e8fc515e0cba380790d             CHANGES.txt
# 98823  15f355a0062148e1ca511e8fc515e0cba380790d      SSTableLoader.java
# 98824  15f355a0062148e1ca511e8fc515e0cba380790d  SSTableLoaderTest.java
#
# [98825 rows x 2 columns]

# %%
issue_df
# Out:
#                                     CommitHash         IssueID
# 0     9164940f41972e3611d1ad38a903ca39562e6feb   CASSANDRA-263
# 1     ef203cf00070fd719f87db9dd2384b8bc116ebd6   CASSANDRA-262
# 2     cdd8b170628176924c21db1cb6dcbecf4c7f2148   CASSANDRA-261
# 3     74dcfb263ca695534ec631d8cf11f909e54a9765   CASSANDRA-163
# 4     af47dc8476a6e4e4856476e4acff1ac8321a6a39   CASSANDRA-163
# ...                                        ...             ...
# 1775  bb36090fa0858456fb1ba80adf71fb3dc24a1aac  CASSANDRA-9914
# 1776  6c90950489a42a38a6ddfa45f79c84a110dffbe7  CASSANDRA-9880
# 1777  c1bf002234bd44bce120658e9b08b3d67901e5bb  CASSANDRA-9814
# 1778  738dfde73560d289218f3afa4103a37e9f401757  CASSANDRA-9814
# 1779  9be8369ae65be8eb4848eb9ef58e2909a8d89016  CASSANDRA-9680
#
# [1780 rows x 2 columns]

# %%
# 6. Correlation Analysis
# Group by files and count how many times each file appears in issues
file_issue_counts = issue_df['IssueID'].groupby(issue_df['CommitHash']).count().reset_index()

# %%
# Merge with commit data
merged_data = pd.merge(commit_df, file_issue_counts, on='CommitHash', how='left')

# %%
# Create a table showing files and the number of times they appeared in issues
file_issue_summary = merged_data.groupby('ModifiedFile')['IssueID'].sum().reset_index()
file_issue_summary.rename(columns={'IssueID': 'TimesAppearedInIssues'}, inplace=True)

# %%
file_issue_summary.sort_values(by='TimesAppearedInIssues', ascending=False).head(50)
# Out:
#                        ModifiedFile  TimesAppearedInIssues
# 683                     CHANGES.txt                  946.0
# 5476            StorageService.java                  160.0
# 1076         ColumnFamilyStore.java                  139.0
# 1603        DatabaseDescriptor.java                   90.0
# 6459                      build.xml                   82.0
# 1251         CompactionManager.java                   72.0
# 5473              StorageProxy.java                   71.0
# 6633                 cassandra.yaml                   67.0
# 3649                       NEWS.txt                   63.0
# 1355                    Config.java                   58.0
# 676                 CFMetaData.java                   55.0
# 3492          MessagingService.java                   50.0
# 4817             SSTableReader.java                   47.0
# 2263                  Gossiper.java                   44.0
# 838            CassandraServer.java                   43.0
# 4987           SelectStatement.java                   39.0
# 3743                 NodeProbe.java                   39.0
# 6859                          cqlsh                   37.0
# 3398                  Memtable.java                   37.0
# 2383      HintedHandOffManager.java                   33.0
# 932                  CliClient.java                   32.0
# 5674                     Table.java                   32.0
# 1166                 CommitLog.java                   32.0
# 803            CassandraDaemon.java                   28.0
# 844           CassandraStorage.java                   27.0
# 3735                   NodeCmd.java                   27.0
# 4847             SSTableWriter.java                   27.0
# 4257            QueryProcessor.java                   26.0
# 1458                          Cql.g                   25.0
# 5481       StorageServiceMBean.java                   25.0
# 3522          MigrationManager.java                   24.0
# 715                     CQL.textile                   24.0
# 4916              SchemaLoader.java                   22.0
# 3184           LeveledManifest.java                   22.0
# 6588               cassandra-env.sh                   22.0
# 5656               SystemTable.java                   21.0
# 6821                cql3handling.py                   21.0
# 1965               FBUtilities.java                   21.0
# 1072  ColumnFamilyRecordReader.java                   21.0
# 1268            CompactionTask.java                   20.0
# 5645            SystemKeyspace.java                   19.0
# 237        AlterTableStatement.java                   18.0
# 1234      CompactionController.java                   18.0
# 1082     ColumnFamilyStoreTest.java                   18.0
# 3135        LazilyCompactedRow.java                   17.0
# 1731               Directories.java                   17.0
# 253         AntiEntropyService.java                   16.0
# 4943                  Scrubber.java                   16.0
# 1598               DataTracker.java                   16.0
# 4142           PrecompactedRow.java                   16.0

# %%
# 7. Analyze Results
# DataFrame (file_issue_summary) that contains information about how many times each modified file appeared in issues.
# Analyze and visualize this data to draw conclusions about the correlation between file modifications and issues.

# %%
file_issue_summary[file_issue_summary['ModifiedFile'].str.contains(".java")].sort_values(by='TimesAppearedInIssues', ascending=False).head(50)
# Out:
#                           ModifiedFile  TimesAppearedInIssues
# 5476               StorageService.java                  160.0
# 1076            ColumnFamilyStore.java                  139.0
# 1603           DatabaseDescriptor.java                   90.0
# 1251            CompactionManager.java                   72.0
# 5473                 StorageProxy.java                   71.0
# 1355                       Config.java                   58.0
# 676                    CFMetaData.java                   55.0
# 3492             MessagingService.java                   50.0
# 4817                SSTableReader.java                   47.0
# 2263                     Gossiper.java                   44.0
# 838               CassandraServer.java                   43.0
# 3743                    NodeProbe.java                   39.0
# 4987              SelectStatement.java                   39.0
# 3398                     Memtable.java                   37.0
# 2383         HintedHandOffManager.java                   33.0
# 1166                    CommitLog.java                   32.0
# 932                     CliClient.java                   32.0
# 5674                        Table.java                   32.0
# 803               CassandraDaemon.java                   28.0
# 4847                SSTableWriter.java                   27.0
# 3735                      NodeCmd.java                   27.0
# 844              CassandraStorage.java                   27.0
# 4257               QueryProcessor.java                   26.0
# 5481          StorageServiceMBean.java                   25.0
# 3522             MigrationManager.java                   24.0
# 3184              LeveledManifest.java                   22.0
# 4916                 SchemaLoader.java                   22.0
# 5656                  SystemTable.java                   21.0
# 1072     ColumnFamilyRecordReader.java                   21.0
# 1965                  FBUtilities.java                   21.0
# 1268               CompactionTask.java                   20.0
# 5645               SystemKeyspace.java                   19.0
# 1234         CompactionController.java                   18.0
# 1082        ColumnFamilyStoreTest.java                   18.0
# 237           AlterTableStatement.java                   18.0
# 3135           LazilyCompactedRow.java                   17.0
# 1731                  Directories.java                   17.0
# 132   AbstractReplicationStrategy.java                   16.0
# 253            AntiEntropyService.java                   16.0
# 4943                     Scrubber.java                   16.0
# 1598                  DataTracker.java                   16.0
# 4142              PrecompactedRow.java                   16.0
# 5870                TokenMetadata.java                   15.0
# 5798             ThriftValidation.java                   15.0
# 1277              CompactionsTest.java                   15.0
# 3581        ModificationStatement.java                   14.0
# 4788      SSTableIdentityIterator.java                   14.0
# 4710                  RowMutation.java                   14.0
# 4951        SecondaryIndexManager.java                   14.0
# 4893                       Schema.java                   14.0

# %% [markdown]
# # Testa correlação entre os arquivos que aparecem em muito issues e os arquivos críticos identificados via ATDCodeAnalyzer

# %% [markdown]
# ## Lista de arquivos críticos identificados pelo ATDCodeAnalyzer

# %%
lista_arquivos_criticos = [("StorageService.java", 3537, 144), ("ColumnFamilyStore.java", 1966, 89), ("DatabaseDescriptor.java", 2092, 87), ("CompactionManager.java", 1279, 74), ("StorageProxy.java", 1667, 53), ("SSTableReader.java", 767, 53), ("Config.java", 553, 52), ("CassandraDaemon.java", 1001, 51), ("SelectStatement.java", 1174, 44), ("SinglePartitionReadCommand.java", 994, 38),("NodeProbe.java", 513, 37), ("MessagingService.java", 574, 36)]
lista_arquivos_criticos
# Out:
# [('StorageService.java', 3537, 144),
#  ('ColumnFamilyStore.java', 1966, 89),
#  ('DatabaseDescriptor.java', 2092, 87),
#  ('CompactionManager.java', 1279, 74),
#  ('StorageProxy.java', 1667, 53),
#  ('SSTableReader.java', 767, 53),
#  ('Config.java', 553, 52),
#  ('CassandraDaemon.java', 1001, 51),
#  ('SelectStatement.java', 1174, 44),
#  ('SinglePartitionReadCommand.java', 994, 38),
#  ('NodeProbe.java', 513, 37),
#  ('MessagingService.java', 574, 36)]

# %%
lista_nomes_arquivos_criticos = []
for item in lista_arquivos_criticos:
  lista_nomes_arquivos_criticos.append(item[0])

list_file, list_amloc, list_foc = list(), list(), list()

for each in lista_arquivos_criticos:
  file, amloc, foc = each[0], each[1], each[2]
  list_file.append(file)
  list_amloc.append(amloc)
  list_foc.append(foc)

dict_critical_files_by_atd = {
    'file':list_file, 'AMLOC':list_amloc, 'FOC':list_foc
}

df_dict_critical_files_by_atd = pd.DataFrame(dict_critical_files_by_atd)
df_dict_critical_files_by_atd
# Out:
#                                file  AMLOC  FOC
# 0               StorageService.java   3537  144
# 1            ColumnFamilyStore.java   1966   89
# 2           DatabaseDescriptor.java   2092   87
# 3            CompactionManager.java   1279   74
# 4                 StorageProxy.java   1667   53
# 5                SSTableReader.java    767   53
# 6                       Config.java    553   52
# 7              CassandraDaemon.java   1001   51
# 8              SelectStatement.java   1174   44
# 9   SinglePartitionReadCommand.java    994   38
# 10                   NodeProbe.java    513   37
# 11            MessagingService.java    574   36

# %%
# !wget https://raw.githubusercontent.com/mining-software-repositories/cassandra/main/data/my_composition.csv
# Out:
# --2023-09-15 14:40:26--  https://raw.githubusercontent.com/mining-software-repositories/cassandra/main/data/my_composition.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 86608 (85K) [text/plain]
# Saving to: ‘my_composition.csv.1’
#
# my_composition.csv. 100%[===================>]  84.58K  --.-KB/s    in 0.02s
#
# 2023-09-15 14:40:26 (4.97 MB/s) - ‘my_composition.csv.1’ saved [86608/86608]

# %%
# Todos os arquivos do repositório cassandra
df_cassandra_atd = pd.read_csv('my_composition.csv')
df_cassandra_atd['composition'] = df_cassandra_atd['fc'] *  df_cassandra_atd['ml'] * df_cassandra_atd['cc']
df_cassandra_atd.sort_values(by='composition', ascending=False)
# Out:
#                              filename   fc    ml   cc  composition
# 168               StorageService.java  144  3537  838    426816864
# 402                       copyutil.py   49  8427  588    242798724
# 1             DatabaseDescriptor.java   87  2092  471     85723884
# 14             ColumnFamilyStore.java   89  1966  373     65265302
# 316                          cqlsh.py   55  1351  458     34031690
# ...                               ...  ...   ...  ...          ...
# 1560                 mb-3-big-TOC.txt    1     8    0            0
# 1561                      __init__.py    1     6    0            0
# 1562             BaseRowIterator.java    1     2    0            0
# 1567  DynamicEndpointSnitchMBean.java    2    28    0            0
# 1321               SampleOfLongs.java    1   111    0            0
#
# [2643 rows x 5 columns]

# %%
list_file, list_amloc, list_foc, list_cc = list(), list(), list(), list()

for i in df_cassandra_atd.index:
  if df_cassandra_atd['filename'][i] in lista_nomes_arquivos_criticos:
    file = df_cassandra_atd['filename'][i]
    amloc = df_cassandra_atd['ml'][i]
    foc = df_cassandra_atd['fc'][i]
    cc = df_cassandra_atd['cc'][i]
    list_file.append(file)
    list_amloc.append(amloc)
    list_foc.append(foc)
    list_cc.append(cc)

dict_critical_files_by_atd = {
    'file':list_file, 'AMLOC':list_amloc, 'FOC':list_foc, 'CC':list_cc
}

df_critical_files_by_atd = pd.DataFrame(dict_critical_files_by_atd)
df_critical_files_by_atd
# Out:
#                                file  AMLOC  FOC   CC
# 0                       Config.java    553   52   12
# 1           DatabaseDescriptor.java   2092   87  471
# 2            ColumnFamilyStore.java   1966   89  373
# 3              CassandraDaemon.java   1001   51  117
# 4              SelectStatement.java   1174   44  177
# 5   SinglePartitionReadCommand.java    994   38  157
# 6             MessagingService.java    574   36  165
# 7                 StorageProxy.java   1667   53  377
# 8            CompactionManager.java   1279   74  265
# 9               StorageService.java   3537  144  838
# 10                   NodeProbe.java    513   37  255
# 11               SSTableReader.java    767   53  324

# %%
df_critical_files_by_atd['composition'] = df_critical_files_by_atd['AMLOC'] * df_critical_files_by_atd['FOC'] * df_critical_files_by_atd['CC']
df_critical_files_by_atd.sort_values(by='composition', ascending=False)
# Out:
#                                file  AMLOC  FOC   CC  composition
# 9               StorageService.java   3537  144  838    426816864
# 1           DatabaseDescriptor.java   2092   87  471     85723884
# 2            ColumnFamilyStore.java   1966   89  373     65265302
# 7                 StorageProxy.java   1667   53  377     33308327
# 8            CompactionManager.java   1279   74  265     25081190
# 11               SSTableReader.java    767   53  324     13170924
# 4              SelectStatement.java   1174   44  177      9143112
# 3              CassandraDaemon.java   1001   51  117      5972967
# 5   SinglePartitionReadCommand.java    994   38  157      5930204
# 10                   NodeProbe.java    513   37  255      4840155
# 6             MessagingService.java    574   36  165      3409560
# 0                       Config.java    553   52   12       345072

# %% [markdown]
# ## Relação de arquivos que aparecem em muitos issues

# %%
df_files_in_issues = file_issue_summary[file_issue_summary['ModifiedFile'].str.contains(".java")].sort_values(by='TimesAppearedInIssues', ascending=False)
df_files_in_issues
# Out:
#                  ModifiedFile  TimesAppearedInIssues
# 5476      StorageService.java                  160.0
# 1076   ColumnFamilyStore.java                  139.0
# 1603  DatabaseDescriptor.java                   90.0
# 1251   CompactionManager.java                   72.0
# 5473        StorageProxy.java                   71.0
# ...                       ...                    ...
# 2516    IMessageCallback.java                    0.0
# 2515            IMessage.java                    0.0
# 2514      IMergeIterator.java                    0.0
# 2513   IMeasurableMemory.java                    0.0
# 8394          udfcontext.java                    0.0
#
# [6082 rows x 2 columns]

# %%
df_files_in_issues.sort_values(by='TimesAppearedInIssues', ascending=False).head(50)
# Out:
#                           ModifiedFile  TimesAppearedInIssues
# 5476               StorageService.java                  160.0
# 1076            ColumnFamilyStore.java                  139.0
# 1603           DatabaseDescriptor.java                   90.0
# 1251            CompactionManager.java                   72.0
# 5473                 StorageProxy.java                   71.0
# 1355                       Config.java                   58.0
# 676                    CFMetaData.java                   55.0
# 3492             MessagingService.java                   50.0
# 4817                SSTableReader.java                   47.0
# 2263                     Gossiper.java                   44.0
# 838               CassandraServer.java                   43.0
# 3743                    NodeProbe.java                   39.0
# 4987              SelectStatement.java                   39.0
# 3398                     Memtable.java                   37.0
# 2383         HintedHandOffManager.java                   33.0
# 5674                        Table.java                   32.0
# 932                     CliClient.java                   32.0
# 1166                    CommitLog.java                   32.0
# 803               CassandraDaemon.java                   28.0
# 4847                SSTableWriter.java                   27.0
# 3735                      NodeCmd.java                   27.0
# 844              CassandraStorage.java                   27.0
# 4257               QueryProcessor.java                   26.0
# 5481          StorageServiceMBean.java                   25.0
# 3522             MigrationManager.java                   24.0
# 3184              LeveledManifest.java                   22.0
# 4916                 SchemaLoader.java                   22.0
# 5656                  SystemTable.java                   21.0
# 1072     ColumnFamilyRecordReader.java                   21.0
# 1965                  FBUtilities.java                   21.0
# 1268               CompactionTask.java                   20.0
# 5645               SystemKeyspace.java                   19.0
# 237           AlterTableStatement.java                   18.0
# 1234         CompactionController.java                   18.0
# 1082        ColumnFamilyStoreTest.java                   18.0
# 1731                  Directories.java                   17.0
# 3135           LazilyCompactedRow.java                   17.0
# 132   AbstractReplicationStrategy.java                   16.0
# 253            AntiEntropyService.java                   16.0
# 4943                     Scrubber.java                   16.0
# 1598                  DataTracker.java                   16.0
# 4142              PrecompactedRow.java                   16.0
# 5870                TokenMetadata.java                   15.0
# 5798             ThriftValidation.java                   15.0
# 1277              CompactionsTest.java                   15.0
# 4710                  RowMutation.java                   14.0
# 4951        SecondaryIndexManager.java                   14.0
# 4893                       Schema.java                   14.0
# 4788      SSTableIdentityIterator.java                   14.0
# 3581        ModificationStatement.java                   14.0

# %% [markdown]
# ### Filtra apenas os arquivos que aparecem no ATDCodeAnalyzer

# %%
list_file, list_appears_in_issues = list(), list()

for i in df_files_in_issues.index:
  if df_files_in_issues['ModifiedFile'][i] in lista_nomes_arquivos_criticos:
    file = df_files_in_issues['ModifiedFile'][i]
    appears_in_issues = df_files_in_issues['TimesAppearedInIssues'][i]
    list_file.append(file)
    list_appears_in_issues.append(appears_in_issues)

dict_critical_files_by_issues = {
    'file':list_file, 'appears_in_issues':list_appears_in_issues
}

df_critical_files_by_issues = pd.DataFrame(dict_critical_files_by_issues)
df_critical_files_by_issues
# Out:
#                                file  appears_in_issues
# 0               StorageService.java              160.0
# 1            ColumnFamilyStore.java              139.0
# 2           DatabaseDescriptor.java               90.0
# 3            CompactionManager.java               72.0
# 4                 StorageProxy.java               71.0
# 5                       Config.java               58.0
# 6             MessagingService.java               50.0
# 7                SSTableReader.java               47.0
# 8                    NodeProbe.java               39.0
# 9              SelectStatement.java               39.0
# 10             CassandraDaemon.java               28.0
# 11  SinglePartitionReadCommand.java                5.0

# %% [markdown]
# ### Faz a composição dos dados dos arquivos em muitos issues e dos arquivos identificados via ATDCodeAnalyzer

# %%
df_critical_files_by_atd.sort_values(by='composition', ascending=False)
# Out:
#                                file  AMLOC  FOC   CC  composition
# 9               StorageService.java   3537  144  838    426816864
# 1           DatabaseDescriptor.java   2092   87  471     85723884
# 2            ColumnFamilyStore.java   1966   89  373     65265302
# 7                 StorageProxy.java   1667   53  377     33308327
# 8            CompactionManager.java   1279   74  265     25081190
# 11               SSTableReader.java    767   53  324     13170924
# 4              SelectStatement.java   1174   44  177      9143112
# 3              CassandraDaemon.java   1001   51  117      5972967
# 5   SinglePartitionReadCommand.java    994   38  157      5930204
# 10                   NodeProbe.java    513   37  255      4840155
# 6             MessagingService.java    574   36  165      3409560
# 0                       Config.java    553   52   12       345072

# %%
df_result = pd.merge(df_critical_files_by_issues, df_critical_files_by_atd, on='file', how='inner')
df_result
# Out:
#                                file  appears_in_issues  AMLOC  FOC   CC  \
# 0               StorageService.java              160.0   3537  144  838
# 1            ColumnFamilyStore.java              139.0   1966   89  373
# 2           DatabaseDescriptor.java               90.0   2092   87  471
# 3            CompactionManager.java               72.0   1279   74  265
# 4                 StorageProxy.java               71.0   1667   53  377
# 5                       Config.java               58.0    553   52   12
# 6             MessagingService.java               50.0    574   36  165
# 7                SSTableReader.java               47.0    767   53  324
# 8                    NodeProbe.java               39.0    513   37  255
# 9              SelectStatement.java               39.0   1174   44  177
# 10             CassandraDaemon.java               28.0   1001   51  117
# 11  SinglePartitionReadCommand.java                5.0    994   38  157
#
#     composition
# 0     426816864
# 1      65265302
# 2      85723884
# 3      25081190
# 4      33308327
# 5        345072
# 6       3409560
# 7      13170924
# 8       4840155
# 9       9143112
# 10      5972967
# 11      5930204

# %% [markdown]
# ### Faz correlação entre os atributos: AMLOC, FOC, CC e appears_in_issues

# %%
import seaborn as sns

# calculate the correlation matrix on the numeric columns
corr = df_result.select_dtypes('number').corr()

sns.heatmap(corr, cmap='Blues')
# Out:
# <Axes: >
